# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')


import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem.EState import Fingerprinter
from rdkit.Chem import Descriptors
from rdkit.Chem.rdmolops import RDKFingerprint

file = "BradleyDoublePlusGoodMeltingPointDataset.xlsx"
data = pd.read_excel(file, usecols = ['smiles','mpC'])

print ("the number of data point is ", data.shape)


fp_case = 9
fp_len = 128
# Out:
# the number of data point is  (3041, 2)

# %%
all_smiles = data['smiles'].values
all_y = data['mpC'].values

print ("THESE SMILES STRINGS ARE NOT CORRECT, REMOVE DATA:")

smiles = []
y = []
for idx in range(len(all_smiles)):
    tsmiles = all_smiles[idx]
    tmol = Chem.MolFromSmiles(tsmiles, sanitize=False)
    problems = Chem.DetectChemistryProblems(tmol)
    if (len(problems)>0):
        print (tsmiles)
    else:
        smiles.append(tsmiles)
        y.append(all_y[idx])
# Out:
# THESE SMILES STRINGS ARE NOT CORRECT, REMOVE DATA:
# c1cccn1
# N#Cc3cncc3c1cccc2OC(F)(F)Oc12
# COc1cc(cc(OC)c1OC)/C=C/C(=O)O[C@@H]3C[C@@H]4CN5CCc2c6ccc(OC)cc6nc2[C@H]5C[C@@H]4[C@@H]([C@H]3OC)C(=O)OC
# c1cncn1
# c1cccc2nccc12
# Cc1cc2nnnc2cc1
# O=C(OC)[C@@]2(C[C@H]4C[C@@](O)(CC)C[N@@](CCc1c3ccccc3nc12)C4)c5cc9c(cc5OC)N(C=O)[C@@H]6[C@]98CCN7CC=C[C@@](CC)([C@@H](OC(C)=O)[C@]6(O)C(=O)OC)[C@H]78
# [O-][N+](=O)c1ccc2ncnc2c1
# [O-][N+](=O)c1cnc(C)n1
# c1cccc2ncnc12
# Cc2cnc1ccccc12
# c1cccc2nnnc12
# n2cnc(NCc1ccccc1)c3ncnc23
# n1c3ccccc3nc1c2cscn2
# N[C@@H](Cc1cncn1)C(=O)O
# Sc1nc2ccccc2n1
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 24 25 26 27 28 31 32 33 34
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5 6 7 8 9
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 16 17 18 19 20 21 22 23 24
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 3 4 5 6 7 8 9 10 11
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 3 4 5 6 8
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5 6 7 8 9
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 12 13 14 15 16
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 3 4 5 6 7
# RDKit ERROR:
# RDKit ERROR: [21:48:06] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5 6 7 8 9
# RDKit ERROR:

# %%
data = pd.DataFrame(list(zip(smiles, y)), columns = ['smiles', 'mpC'])
data['Mol'] = data['smiles'].apply(Chem.MolFromSmiles)

# %%
data.head()
# Out:
#                                        smiles     mpC  \
# 0                                   C1(CCC1)C -161.51
# 1                                  [O-][N+]#N  -90.80
# 2                                 FS(F)(=O)=O -135.80
# 3  CC(C)N(CCC(c1ccccn1)(c2ccccc2)C(N)=O)C(C)C   94.80
# 4                                        BrBr   -7.20
#
#                                                 Mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f28f867a350>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f28f8ebabc0>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f28f9eeaa80>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f28f9ee0710>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f28f9ee08a0>

# %%
from rdkit.Chem.rdMolDescriptors import *

from rdkit.Chem.AtomPairs.Sheridan import GetBPFingerprint
from rdkit.Chem.EState.Fingerprinter import FingerprintMol
from rdkit.Avalon.pyAvalonTools import GetAvalonFP
from rdkit.Chem.AllChem import  GetMorganFingerprintAsBitVect, GetErGFingerprint
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray
import rdkit.DataStructs.cDataStructs

from rdkit import Chem, DataStructs, RDConfig
from rdkit.Chem import AllChem
from rdkit.Chem.Pharm2D import Gobbi_Pharm2D, Generate

from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors3D

# %%
from rdkit.Chem import rdqueries
def element_count(mol, Zelement):
    q = rdqueries.AtomNumEqualsQueryAtom(Zelement)
    return len(mol.GetAtomsMatchingQuery(q))

# %%
from sklearn.preprocessing import StandardScaler

def generate_fingerprint(mol, fp_case, fp_len):
    #print ("Using the fingerprint:")
    if (fp_case==0):
        #print ("Estate (1995)")
        return FingerprintMol(mol)[0]
    elif (fp_case==1):
        #print ("Morgan circular")
        return GetMorganFingerprintAsBitVect(mol, 2, fp_len)
    elif (fp_case==2):
        #print ("Atom pair (1985)")
        return GetHashedAtomPairFingerprintAsBitVect(mol, fp_len)
    elif (fp_case==3):
        print ("Topological torsion (1987)")
        return GetHashedTopologicalTorsionFingerprintAsBitVect(mol, fp_len)
    elif (fp_case==4):
        print ("Avalon bit based (2006)")
        return GetAvalonFP(mol, fp_len)
    elif (fp_case==5):
        print ("Avalon+mol. weight")
        return np.append(GetAvalonFP(mol, fp_len), Descriptors.MolWt(mol))
    elif (fp_case==6):
        print ("RDKit fingerprint")
        return RDKFingerprint(mol, fpSize=fp_len)
    elif (fp_case==7):
        print ("ErG fingerprint (2006)")
        return GetErGFingerprint(mol)
    elif (fp_case==8):
        AllChem.EmbedMolecule(mol)
        factory = Gobbi_Pharm2D.factory
        return Generate.Gen2DFingerprint( mol, factory)
        #, dMat = Chem.Get3DDistanceMatrix(mol) )
    elif (fp_case==9):
        mol = Chem.AddHs(mol)
        #ps = AllChem.ETKDGv2()
        #ps.randomSeed = 0xf00d
        #AllChem.EmbedMolecule(mol,ps)
        AllChem.EmbedMolecule(mol)
        return rdMolDescriptors.CalcAUTOCORR3D(mol)
    


#Scale X to unit variance and zero mean
data['Fingerprint'] = data['Mol'].apply(generate_fingerprint, fp_case=fp_case, fp_len=fp_len)

fp_element_count = False
fp_add_fp2 = False
fp_add_fp3 = False

X = np.array(list(data['Fingerprint']))
if fp_element_count:
    data['C_count'] = data['Mol'].apply(element_count, Zelement=6)
    data['N_count'] = data['Mol'].apply(element_count, Zelement=7)
    data['O_count'] = data['Mol'].apply(element_count, Zelement=8)
    X1 = data[['C_count','N_count','O_count']].values
    X = np.concatenate((X,X1), axis=1)
if fp_add_fp2:
    data['Fingerprint_2'] = data['Mol'].apply(generate_fingerprint, fp_case=fp_case+1, fp_len=fp_len)
    X2 = np.array(list(data['Fingerprint_2']))
    X = np.concatenate((X,X2), axis=1)
if fp_add_fp3:
    data['Fingerprint_3'] = data['Mol'].apply(generate_fingerprint, fp_case=fp_case+2, fp_len=fp_len)
    X3 = np.array(list(data['Fingerprint_3']))
    X = np.concatenate((X,X3), axis=1)

st = StandardScaler()
X = st.fit_transform(X)
# Out:
# RDKit ERROR: [21:48:21] UFFTYPER: Unrecognized charge state for atom: 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-044397386e67> in <module>
#      43
#      44 #Scale X to unit variance and zero mean
# ---> 45 data['Fingerprint'] = data['Mol'].apply(generate_fingerprint, fp_case=fp_case, fp_len=fp_len)
#      46
#      47 fp_element_count = False
#
# ~/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/series.py in f(x)
#    4091
#    4092             def f(x):
# -> 4093                 return func(x, *args, **kwds)
#    4094
#    4095         else:
#
# <ipython-input-7-044397386e67> in generate_fingerprint(mol, fp_case, fp_len)
#      38         #AllChem.EmbedMolecule(mol,ps)
#      39         AllChem.EmbedMolecule(mol)
# ---> 40         return rdMolDescriptors.CalcAUTOCORR3D(mol)
#      41
#      42
#
# RuntimeError: Pre-condition Violation
# 	molecule has no conformers
# 	Violation occurred on line 238 in file Code/GraphMol/Descriptors/AUTOCORR3D.cpp
# 	Failed Expression: mol.getNumConformers() >= 1
# 	RDKIT: 2020.09.1
# 	BOOST: 1_73

# %%
huy = aaa

# %%
doravirine = Chem.AddHs(Chem.MolFromSmiles('Cn1c(n[nH]c1=O)Cn2ccc(c(c2=O)Oc3cc(cc(c3)Cl)C#N)C(F)(F)F'))
ps = AllChem.ETKDGv2()
ps.randomSeed = 0xf00d
AllChem.EmbedMolecule(doravirine,ps)
#IPythonConsole.drawMol3D(doravirine)
# Out:
# 0

# %%
print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(doravirine)))
print("Morse:",len(rdMolDescriptors.CalcMORSE(doravirine)))
print("RDF:",len(rdMolDescriptors.CalcRDF(doravirine)))
print("WHIM:",len(rdMolDescriptors.CalcWHIM(doravirine)))
print("GETAWAY:",len(rdMolDescriptors.CalcGETAWAY(doravirine)))
# Out:
# AutoCorr3D: 80
# Morse: 224
# RDF: 210
# WHIM: 114
# GETAWAY: 273

# %%
for tsmiles in smiles:
    print (tsmiles)
    tmol = Chem.MolFromSmiles(tsmiles)
    #tmol = Chem.AddHs(Chem.MolFromSmiles(tsmiles))
    #tmol = Chem.MolFromMolBlock(Chem.MolFromSmiles(tsmiles), sanitize=False)
    tmol.UpdatePropertyCache(strict=False)
    tmol = Chem.AddHs(tmol, addCoords=True)
    #ps = AllChem.ETKDGv2()
    #ps.randomSeed = 0xf00d
    #AllChem.EmbedMolecule(tmol,ps)
    AllChem.EmbedMolecule(tmol)
    print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(tmol)))
# Out:
# C1(CCC1)C
# AutoCorr3D: 80
# [O-][N+]#N
# AutoCorr3D: 80
# FS(F)(=O)=O
# AutoCorr3D: 80
# CC(C)N(CCC(c1ccccn1)(c2ccccc2)C(N)=O)C(C)C
# AutoCorr3D: 80
# BrBr
# AutoCorr3D: 80
# O=C(O)C2=CN(CC)c1c(F)c(c(F)cc1C2=O)N3CC(C)NCC3
# AutoCorr3D: 80
# CN(C)C
# AutoCorr3D: 80
# ClC(Cl)(Cl)Cl
# AutoCorr3D: 80
# II
# AutoCorr3D: 80
# C#C
# AutoCorr3D: 80
# CC(Cl)Cl
# AutoCorr3D: 80
# CC(CO)(CO)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cc(sc1)Cl
# AutoCorr3D: 80
# CCCOC(=O)CC
# AutoCorr3D: 80
# CC(=C)OC(=O)C
# AutoCorr3D: 80
# CCCOC=O
# AutoCorr3D: 80
# Cc1c(cc(cc1[N+](=O)[O-])[N+]([O-])=O)[N+]([O-])=O
# AutoCorr3D: 80
# CCc1cccc(CC)c1
# AutoCorr3D: 80
# CC(=CCCC(=O)C)C
# AutoCorr3D: 80
# CC(C)C(C)(C)CC
# AutoCorr3D: 80
# CC(C)(CC)CCC
# AutoCorr3D: 80
# CC(C)(C)CCCC
# AutoCorr3D: 80
# C=C(C)C(C)(C)C
# AutoCorr3D: 80
# CC(C)C(CC)CC
# AutoCorr3D: 80
# CCSCCCC
# AutoCorr3D: 80
# Cc1ccc(CC)cc1C
# AutoCorr3D: 80
# CC(CC)(CC)CC
# AutoCorr3D: 80
# CC(C)CC(C)C(C)C
# AutoCorr3D: 80
# CC(C)CCCC(C)C
# AutoCorr3D: 80
# CC=1CCCCC=1C
# AutoCorr3D: 80
# CCCC1CCCCC1
# AutoCorr3D: 80
# C(=C(Cl)Cl)(C(Cl)(Cl)Cl)Cl
# AutoCorr3D: 80
# CCc1cc(C)cc(CC)c1
# AutoCorr3D: 80
# C=C(C)CC(C)C
# AutoCorr3D: 80
# C/C(C)=C(/C)CCC
# AutoCorr3D: 80
# CC(C)C(C)(C)C(C)C
# AutoCorr3D: 80
# CCC=1CCCCC=1
# AutoCorr3D: 80
# C1CC1CCl
# AutoCorr3D: 80
# CC1CCCC1CC
# AutoCorr3D: 80
# CC1CC=CC1
# AutoCorr3D: 80
# CC1(CC)CCCC1
# AutoCorr3D: 80
# CCC1CC1
# AutoCorr3D: 80
# CC1(CC)CC1
# AutoCorr3D: 80
# CC1CC1(C)C
# AutoCorr3D: 80
# C=CC=C/C
# AutoCorr3D: 80
# Clc1ccc2N=C(C[N+]([O-])=C(c2c1)c3ccccc3)NC
# AutoCorr3D: 80
# CCS
# AutoCorr3D: 80
# C=CC
# AutoCorr3D: 80
# C1(=C(C(=C(C(=C1Cl)Cl)Cl)Cl)Cl)C2=C(C(=C(C(=C2Cl)Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# CN1CCN(C1=O)C
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCBr
# AutoCorr3D: 80
# Cc1cccc(c1)I
# AutoCorr3D: 80
# C1CCN(CC1)C=O
# AutoCorr3D: 80
# Cc1cccc(C)c1CC
# AutoCorr3D: 80
# Cc1cccc(C)c1I
# AutoCorr3D: 80
# CC(C)(C)C(C)(C)CC
# AutoCorr3D: 80
# C(C(F)F)O
# AutoCorr3D: 80
# O=[N+]([O-])C([N+]([O-])=O)([N+](=O)[O-])[N+]([O-])=O
# AutoCorr3D: 80
# Cc1cc(cc(c1)N)C
# AutoCorr3D: 80
# Cc1c(c(c(c(c1F)F)F)F)F
# AutoCorr3D: 80
# Cc1ccccc1C
# AutoCorr3D: 80
# CC(=C)c1ccccc1
# AutoCorr3D: 80
# CCc1ccccc1CC
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# C1COCCO1
# AutoCorr3D: 80
# FC(F)(F)C(=O)O
# AutoCorr3D: 80
# N#CCc1ccccc1
# AutoCorr3D: 80
# Cc1ccc(c(c1)Cl)Cl
# AutoCorr3D: 80
# Clc1cccc(Cl)c1
# AutoCorr3D: 80
# OCc1ccccc1
# AutoCorr3D: 80
# c1ccc2c(c1)CC=C2
# AutoCorr3D: 80
# c1cc(cc(c1)O)C(F)(F)F
# AutoCorr3D: 80
# CN(C)C(=O)N(C)C
# AutoCorr3D: 80
# BrC(C)C(Br)(Br)C
# AutoCorr3D: 80
# Cc1ccccc1c2ccccc2
# AutoCorr3D: 80
# CC(C)(C)c1ccccc1O
# AutoCorr3D: 80
# c1ccnc(c1)CCO
# AutoCorr3D: 80
# CCCCCCCCCCCC(=O)OC
# AutoCorr3D: 80
# Cc1ccc(C)c(C)c1C
# AutoCorr3D: 80
# C(CCI)CI
# AutoCorr3D: 80
# CCC(=O)c1ccc(cc1)C
# AutoCorr3D: 80
# CC(C)(C)c1cccc(n1)C(C)(C)C
# AutoCorr3D: 80
# CC#CCO
# AutoCorr3D: 80
# C1CNCCO1
# AutoCorr3D: 80
# CCc1ccc(cc1)N
# AutoCorr3D: 80
# CCN
# AutoCorr3D: 80
# CCOC(=O)C(C)C
# AutoCorr3D: 80
# CCCC(=O)OCCC(C)C
# AutoCorr3D: 80
# CC(C)COC(=O)C
# AutoCorr3D: 80
# B(OCC)(OCC)OCC
# AutoCorr3D: 80
# AutoCorr3D: 80
# CCCCCC
# AutoCorr3D: 80
# C(Cl)(Cl)(Cl)Br
# AutoCorr3D: 80
# CC(C)CCCCCCCCCCCCCCC
# AutoCorr3D: 80
# COCC(=O)O
# AutoCorr3D: 80
# CCCCCCCCCCCCC
# AutoCorr3D: 80
# CC(=O)OO
# AutoCorr3D: 80
# CCCCCCCCCCC1CCCCC1
# AutoCorr3D: 80
# Ic1ccccc1Cl
# AutoCorr3D: 80
# CCCCCCCCCCCCCl
# AutoCorr3D: 80
# Cc1cc(C)c(C)c(C)c1
# AutoCorr3D: 80
# c1cc(cnc1)Br
# AutoCorr3D: 80
# CCCCCCCCCCCl
# AutoCorr3D: 80
# CCCCCCCCCCCCCC(=O)OCC
# AutoCorr3D: 80
# BrC(Br)CBr
# AutoCorr3D: 80
# c1cc(c(cc1F)[N+](=O)[O-])F
# AutoCorr3D: 80
# C(=C(Cl)Cl)(Cl)Cl
# AutoCorr3D: 80
# CC(C)c1ccc(Cl)cc1
# AutoCorr3D: 80
# CC(C)OC(=O)CC(=O)C
# AutoCorr3D: 80
# Ic1cccc(Br)c1
# AutoCorr3D: 80
# c1ccc(cc1)I
# AutoCorr3D: 80
# CCCCCCCCCCI
# AutoCorr3D: 80
# N#Cc1ccccc1
# AutoCorr3D: 80
# CCCCCCCCCC
# AutoCorr3D: 80
# c1ccc2c(c1)C(=O)NS2(=O)=O
# AutoCorr3D: 80
# O=S(C)(=O)c1ccc(cc1)C(O)C(CO)NC(=O)C(Cl)Cl
# AutoCorr3D: 80
# CCCl
# AutoCorr3D: 80
# Cc1ccccc1S(=O)(=O)N
# AutoCorr3D: 80
# Cc1ccnc(n1)N
# AutoCorr3D: 80
# C[C@@H]1CC[C@H](C)C1
# AutoCorr3D: 80
# C=C(C)C(C)CC
# AutoCorr3D: 80
# C=CC(C)(C)CC
# AutoCorr3D: 80
# O=C(N)c1cc(Br)ccc1
# AutoCorr3D: 80
# C/C(C)=CCN1CC[C@@]2(C)c3cc(O)ccc3C[C@@H]1[C@@H]2C
# AutoCorr3D: 80
# C1=CC=C2C(=C1)SC3=CC=CC=C3S2
# AutoCorr3D: 80
# CC(C)C(=C)C
# AutoCorr3D: 80
# C=CCCC=C
# AutoCorr3D: 80
# CCCC(=C)C
# AutoCorr3D: 80
# CC(C)CCC
# AutoCorr3D: 80
# CC=C(/C)C
# AutoCorr3D: 80
# C1=CC(=CC=C1C2=CC=C(C=C2)Cl)Cl
# AutoCorr3D: 80
# CCN(CC)CCNC(=O)c1cc(Cl)c(N)cc1OC
# AutoCorr3D: 80
# CCCCC
# AutoCorr3D: 80
# CCN(CC)CC
# AutoCorr3D: 80
# C(=O)O
# AutoCorr3D: 80
# CCCCC(=O)O
# AutoCorr3D: 80
# C=CCC
# AutoCorr3D: 80
# C=C
# AutoCorr3D: 80
# n1nc(sc1C)N
# AutoCorr3D: 80
# CC(O)(CC)CC
# AutoCorr3D: 80
# CCOP(=O)(OCC)OCC
# AutoCorr3D: 80
# c1ccc2c(c1)CCC2
# AutoCorr3D: 80
# AutoCorr3D: 80
# CC1(C)CC=CCC1
# AutoCorr3D: 80
# CC(C)CC(C)(C)CC
# AutoCorr3D: 80
# C=CC=CC
# AutoCorr3D: 80
# C(F)(Br)(Br)Br
# AutoCorr3D: 80
# CC=1CCCC=1C
# AutoCorr3D: 80
# BrC(=C)CC
# AutoCorr3D: 80
# CC(C)CC#C
# AutoCorr3D: 80
# CCC=CC(C)C
# AutoCorr3D: 80
# C=CCNCC=C
# AutoCorr3D: 80
# CCC
# AutoCorr3D: 80
# CCCCBr
# AutoCorr3D: 80
# C1CCC1
# AutoCorr3D: 80
# O=C(O)CCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# CCCCCI
# AutoCorr3D: 80
# C/C(C)=CCCC
# AutoCorr3D: 80
# CCCC#CC
# AutoCorr3D: 80
# CCCC=CCC
# AutoCorr3D: 80
# CN1CCN(CC1)C2=Nc4cc(Cl)ccc4Nc3ccccc23
# AutoCorr3D: 80
# CCC(CBr)Br
# AutoCorr3D: 80
# C=CCBr
# AutoCorr3D: 80
# CC(=O)OCC
# AutoCorr3D: 80
# CC(C)(C)OC
# AutoCorr3D: 80
# BrCC
# AutoCorr3D: 80
# CCO
# AutoCorr3D: 80
# CCC(=O)O
# AutoCorr3D: 80
# CC=C/CC
# AutoCorr3D: 80
# C1CC1
# AutoCorr3D: 80
# CCCCCCC
# AutoCorr3D: 80
# Cc2ccc(Cc1ccccc1)cc2
# AutoCorr3D: 80
# C1CCCO1
# AutoCorr3D: 80
# CCCCCCC=C
# AutoCorr3D: 80
# CC=1CCCCC=1
# AutoCorr3D: 80
# C=CCCCC
# AutoCorr3D: 80
# C=C(C)C(=O)OC
# AutoCorr3D: 80
# c1ccc2cnccc2c1
# AutoCorr3D: 80
# CO
# AutoCorr3D: 80
# CC(CBr)Br
# AutoCorr3D: 80
# c1c(cc(cc1O)O)O
# AutoCorr3D: 80
# OC(CN)c1ccccc1
# AutoCorr3D: 80
# c1ccnc(c1)C(=O)O
# AutoCorr3D: 80
# NCCCNCCCCN
# AutoCorr3D: 80
# c1cnccc1N
# AutoCorr3D: 80
# COc1cc(ccc1O)CC(=O)O
# AutoCorr3D: 80
# CC(=O)NCCCCCC(=O)O
# AutoCorr3D: 80
# Cc2cc3c1c(cc(cc1O)CCCCC)OC(C)(C)c3cc2
# AutoCorr3D: 80
# CNC(=O)Oc1cccc2CC(C)(C)Oc12
# AutoCorr3D: 80
# CC1(C2CCC(O1)(CC2)C)C
# AutoCorr3D: 80
# COP(=S)(OC)SCC(=O)NC
# AutoCorr3D: 80
# c1ccc(cc1)c2ccc(cc2)CC(=O)O
# AutoCorr3D: 80
# Cc1cc(ccc1SC)OP(=S)(OC)OC
# AutoCorr3D: 80
# Cc1ccc(cc-2c(ccc12)C)C(C)C
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)CO
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)CCC(=O)O
# AutoCorr3D: 80
# S=P(Oc1ccc(cc1)[N+]([O-])=O)(OC)OC
# AutoCorr3D: 80
# CC(=O)NBr
# AutoCorr3D: 80
# COc1ccc(cc1OC)Cc2c3cc(c(cc3ccn2)OC)OC
# AutoCorr3D: 80
# O=C2c1ccccc1C(=O)C2c3ccccc3
# AutoCorr3D: 80
# CC(C)(C)c1ccc(cc1)C(O)CCCN2CCC(CC2)C(O)(c3ccccc3)c4ccccc4
# AutoCorr3D: 80
# NS(=O)(=O)Cc2noc1ccccc12
# AutoCorr3D: 80
# Cc1ccc(cc1)N(CC2=NCCN2)c3cc(O)ccc3
# AutoCorr3D: 80
# O=C1NC(=O)NC(=O)C1(CC)C2=CCCCC2
# AutoCorr3D: 80
# Cc1cc(n[nH]1)C
# AutoCorr3D: 80
# Clc1ccc(cc1)C(C(Cl)Cl)c2ccc(Cl)cc2
# AutoCorr3D: 80
# CC[N+](=O)[O-]
# AutoCorr3D: 80
# CC1(O)CCC(CC1)C(C)(C)O
# AutoCorr3D: 80
# O=C3c1ccccc1C(=O)c2c3ccc(C)c2N
# AutoCorr3D: 80
# Cc1cccc(c1O)C(=O)O
# AutoCorr3D: 80
# C(#N)C1=C(C(=O)C(=C(C1=O)Cl)Cl)C#N
# AutoCorr3D: 80
# c1ccc(cc1)NC(=O)c2ccccc2O
# AutoCorr3D: 80
# COc1c(Cl)cc(Cl)cc1Cl
# AutoCorr3D: 80
# CC(=O)c1cccs1
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(cc([N+]([O-])=O)c1O)[N+]([O-])=O
# AutoCorr3D: 80
# c1ccc(cc1)c2nc(nc(n2)N)N
# AutoCorr3D: 80
# Cc1ccc2c(c1)ccc(=O)o2
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)OC(=O)c2ccccc2
# AutoCorr3D: 80
# CC(CC)=NO
# AutoCorr3D: 80
# c1cc(cc(c1)N)C(F)(F)F
# AutoCorr3D: 80
# c1cc(cc(c1)C(=O)Cl)C(=O)Cl
# AutoCorr3D: 80
# c1cc(cnc1)CO
# AutoCorr3D: 80
# Clc2nc(Nc1ccccc1Cl)nc(Cl)n2
# AutoCorr3D: 80
# C=CC#N
# AutoCorr3D: 80
# CC(C)(C)NC(=O)C=C
# AutoCorr3D: 80
# CC(C)CC(=O)CC(C)C
# AutoCorr3D: 80
# C1CCC(CC1)Br
# AutoCorr3D: 80
# c1cc(cnc1)O
# AutoCorr3D: 80
# c1ccnc(c1)Cl
# AutoCorr3D: 80
# CC(C)CCOC=O
# AutoCorr3D: 80
# CCSSCC
# AutoCorr3D: 80
# C(COCCCl)OCCCl
# AutoCorr3D: 80
# CC(=O)NNc1ccccc1
# AutoCorr3D: 80
# Cc1cc(cc(Br)c1O)C3(OS(=O)(=O)c2ccccc23)c4cc(C)c(O)c(Br)c4
# AutoCorr3D: 80
# c1ccc2c(c1)ccc(n2)c3ccc4ccccc4n3
# AutoCorr3D: 80
# c1ccc(cc1)Cc2cc(ccc2O)Cl
# AutoCorr3D: 80
# O=C(OCC)c1ccc(O)cc1
# AutoCorr3D: 80
# c1cc(c(cc1C(F)(F)F)[N+](=O)[O-])Cl
# AutoCorr3D: 80
# CCOc1cc(ccc1O)C=O
# AutoCorr3D: 80
# O=[N+]([O-])N1CN(CN(C1)[N+]([O-])=O)[N+]([O-])=O
# AutoCorr3D: 80
# c1cc(c(cc1O)O)C(=O)c2ccc(cc2O)O
# AutoCorr3D: 80
# c1ccc(cc1)c2cc(c3ccccc3n2)C(=O)O
# AutoCorr3D: 80
# C(CI)C(=O)O
# AutoCorr3D: 80
# ClCCCCl
# AutoCorr3D: 80
# CC(C)C(C(C)(C)CO)O
# AutoCorr3D: 80
# c1ccc2cnncc2c1
# AutoCorr3D: 80
# c1ccc2Oc3ccccc3Oc2c1
# AutoCorr3D: 80
# c1cc(c(cc1S(=O)(=O)c2ccc(c(c2)[N+](=O)[O-])F)[N+](=O)[O-])F
# AutoCorr3D: 80
# c1cc(c(cc1C(F)(F)F)Cl)Cl
# AutoCorr3D: 80
# c1cc(ncc1C(=O)N)N
# AutoCorr3D: 80
# Clc1ccc(NC(=O)N(C)OC)cc1Cl
# AutoCorr3D: 80
# CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# AutoCorr3D: 80
# CC(=O)Nc1cccc(c1)C(F)(F)F
# AutoCorr3D: 80
# C(=O)(C(C(C(F)(F)F)(F)F)(F)F)O
# AutoCorr3D: 80
# c1cc(cc(c1)C(F)(F)F)C(=O)O
# AutoCorr3D: 80
# Cc1ccc(cc1)S(=O)(=O)F
# AutoCorr3D: 80
# CCOCOCC
# AutoCorr3D: 80
# CCC(=O)C(CC(C)N1CCOCC1)(c2ccccc2)c3ccccc3
# AutoCorr3D: 80
# c1ccc2c(c1)c(ccn2)C(=O)O
# AutoCorr3D: 80
# c1cnc2c(n1)c(=O)[nH]c(=O)[nH]2
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)C=O
# AutoCorr3D: 80
# c1cocc1C(=O)O
# AutoCorr3D: 80
# c1ccc2c(c1)CCc3ccccc3N2
# AutoCorr3D: 80
# C1C=CC(=O)O1
# AutoCorr3D: 80
# c1ccnc(c1)N
# AutoCorr3D: 80
# Cc1ccccc1C(C)C
# AutoCorr3D: 80
# O=[N+]([O-])c1ccccc1[N+]([O-])=O
# AutoCorr3D: 80
# c1ccc(cc1)CSCc2ccccc2
# AutoCorr3D: 80
# CCCCCCCCCCCCCC(=O)CCCCCCCCCCCCC
# AutoCorr3D: 80
# C1C=CC=CC=C1
# AutoCorr3D: 80
# O=C3C=Cc2cccc1cccc3c12
# AutoCorr3D: 80
# C=CC(C)C
# AutoCorr3D: 80
# COc1ccc(c(c1OC)OC)C(=O)O
# AutoCorr3D: 80
# c1ccc2c(c1)cc(c3c2cccc3)Br
# AutoCorr3D: 80
# c1ccc2c(c1)C(=O)N(C2=O)CCBr
# AutoCorr3D: 80
# CCCC(=O)CC
# AutoCorr3D: 80
# CC(C)(C)N=C=S
# AutoCorr3D: 80
# CC1CC=CCC1
# AutoCorr3D: 80
# CCCCOC=O
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# CCC(CC)(CC)O
# AutoCorr3D: 80
# COC(=O)C(Cl)(Cl)Cl
# AutoCorr3D: 80
# [O-][N+](=O)c1ccc2CCc3cccc1c23
# AutoCorr3D: 80
# O=C(C)Oc1ccccc1[N+]([O-])=O
# AutoCorr3D: 80
# CCOC(=O)c1ccco1
# AutoCorr3D: 80
# CC1=CC(=O)OC1=O
# AutoCorr3D: 80
# CC(=O)N[C@@H](CS)C(=O)O
# AutoCorr3D: 80
# CCc1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# CN(C)c1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)OCC(COc2ccccc2)O
# AutoCorr3D: 80
# Cc1ccc(cc1)N=C=S
# AutoCorr3D: 80
# CCOc1ccc(cc1)O
# AutoCorr3D: 80
# CCCCOC
# AutoCorr3D: 80
# CCOCCC
# AutoCorr3D: 80
# CCCCCCCCl
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# CC[Si](CC)(CC)CC
# AutoCorr3D: 80
# O=C(C)Oc1ccccc1OC(C)=O
# AutoCorr3D: 80
# Cc1cc(c(c(c1)O)C)C
# AutoCorr3D: 80
# c1cc(oc1C=O)[N+](=O)[O-]
# AutoCorr3D: 80
# Cc1cc(C)c(C)c(C)c1C
# AutoCorr3D: 80
# c1ccc2c(c1)CCc1ccccc12
# AutoCorr3D: 80
# c1ccc(cc1)P(=O)(c2ccccc2)c3ccccc3
# AutoCorr3D: 80
# C1C2CC3CC1CC(C2)(C3)C(=O)O
# AutoCorr3D: 80
# CC(=O)Oc1cccc2c1cccc2
# AutoCorr3D: 80
# CCCCCC(=O)CCCCC
# AutoCorr3D: 80
# CCc1cccc(C)c1C
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)NN)O
# AutoCorr3D: 80
# CC(C(=O)O)Oc1ccccc1
# AutoCorr3D: 80
# c1ccc(cc1)c2cc3ccccc3[nH]2
# AutoCorr3D: 80
# CC(C)(C)CC(=O)O
# AutoCorr3D: 80
# CC(C)(C)CC(C)(C)C
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccc(cc2)N
# AutoCorr3D: 80
# CCCCCCCCCCCCOC(=O)c1cc(c(c(c1)O)O)O
# AutoCorr3D: 80
# c1ccc2c(c1)CCc3ccccc3C2Cl
# AutoCorr3D: 80
# CC(C)(C)c1cc(cc(c1O)C(C)(C)C)C(=O)O
# AutoCorr3D: 80
# CC(C)SC
# AutoCorr3D: 80
# Cc1ccc(nc1)N
# AutoCorr3D: 80
# CC[Si](CC)(Cl)Cl
# AutoCorr3D: 80
# c1cc(c(cc1Cl)Cl)CO
# AutoCorr3D: 80
# CCCCCCCCOc1ccc(c(c1)O)C(=O)c2ccccc2
# AutoCorr3D: 80
# c1ccc2c(c1)-c3ccccc3C2Br
# AutoCorr3D: 80
# CC(C)c1ccc2ccccc2c1
# AutoCorr3D: 80
# C=Cc1ccccc1Br
# AutoCorr3D: 80
# O=CC1CCCCC1
# AutoCorr3D: 80
# CN1c2ccccc2C(=O)C1=O
# AutoCorr3D: 80
# CC(=O)c1cccc(c1)Br
# AutoCorr3D: 80
# O=C(Nc1cc(ccc1)C(F)(F)F)N(C)C
# AutoCorr3D: 80
# c1(c(c(nc(c1Cl)Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# c1c(c(nc(c1Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# Cc1ccc(c(c1)C(C)(C)C)O
# AutoCorr3D: 80
# Clc1ccccc1/C=C(C#N)C#N
# AutoCorr3D: 80
# COC(=O)c1cc(ccc1Cl)Cl
# AutoCorr3D: 80
# c1c(c(cs1)Br)Br
# AutoCorr3D: 80
# c1cc(sc1Cl)Cl
# AutoCorr3D: 80
# C=CCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# CC(CC)CC=C
# AutoCorr3D: 80
# CCOC(=O)C(C)(C)C
# AutoCorr3D: 80
# C=CC(CC)CC
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCC=C
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# Cc1cc(ccc1Cl)N
# AutoCorr3D: 80
# [SiH](Cl)(Cl)Cl
# AutoCorr3D: 80
# CN(C)c1ccc(cc1)C(=O)OCC
# AutoCorr3D: 80
# Cn1c2ccccc2nn1
# AutoCorr3D: 80
# c1c[n+](ccc1C(=O)O)[O-]
# AutoCorr3D: 80
# CS(=O)(=O)c4ccc3Sc1ccccc1N(CCCN2CCC(CC2)C(N)=O)c3c4
# AutoCorr3D: 80
# c1cc(ncc1Cl)Cl
# AutoCorr3D: 80
# COc1cc(ccc1O)Cl
# AutoCorr3D: 80
# Cc1cc(C)c(C)cc1CC
# AutoCorr3D: 80
# C1=CC=C(C=C1)C2=NC(=C(S2)CC(=O)O)C3=CC=C(C=C3)Cl
# AutoCorr3D: 80
# CC(=O)CCc1ccc(c(c1)OC)O
# AutoCorr3D: 80
# c1ccc(cc1)OCC2CO2
# AutoCorr3D: 80
# Oc1ccc(OCCCC)cc1
# AutoCorr3D: 80
# O=C1CC(=O)CC(C)(C)C1
# AutoCorr3D: 80
# c1ccc(cc1)S(=O)(=O)c2ccccc2
# AutoCorr3D: 80
# BrC(Br)(CBr)CBr
# AutoCorr3D: 80
# CCC(C)(C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([C@H](C=C2)C)CC[C@@H]3C[C@H](CC(=O)O3)O)C
# AutoCorr3D: 80
# CC1(N=C(NC1=O)c2ncccc2C(=O)O)C(C)C
# AutoCorr3D: 80
# C=CCCC(=O)O
# AutoCorr3D: 80
# CCCCCCCCCCCCCC(=O)C
# AutoCorr3D: 80
# C=Cc1ccc(O)cc1
# AutoCorr3D: 80
# CC=CC
# AutoCorr3D: 80
# c1ccc2c(c1)c(=O)[nH]cn2
# AutoCorr3D: 80
# CC(=O)NC12CC3CC(C1)CC(C3)C2
# AutoCorr3D: 80
# CN(C)c1cccc2c1cccc2S(=O)(=O)N
# AutoCorr3D: 80
# Nc2nc(N)ncc2Cc1cc(OC)c(OCCOC)c(OC)c1
# AutoCorr3D: 80
# c1ccc2c(c1)cc(c3c2cccc3)C=O
# AutoCorr3D: 80
# c1ccc(cc1)C2CCC(=O)CC2
# AutoCorr3D: 80
# CCOc1ccc(cc1)CC(=O)O
# AutoCorr3D: 80
# CC(=O)c1ccc(s1)Br
# AutoCorr3D: 80
# Cc1cc(nc(n1)Cl)Cl
# AutoCorr3D: 80
# CCc1cccc(c1)c2ccccc2
# AutoCorr3D: 80
# O=C1CCC(=O)N1O
# AutoCorr3D: 80
# N#CC(=C)C(=O)OCC
# AutoCorr3D: 80
# c1ccc(cc1)OCCC(=O)O
# AutoCorr3D: 80
# CSc1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# Cc1cc(ccc1Cl)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cc(c(c(c1)F)C(=O)N)F
# AutoCorr3D: 80
# c1ccc2c(c1)c3ccc(cc3[nH]2)O
# AutoCorr3D: 80
# c1cc(ccc1C(C(=O)O)O)Br
# AutoCorr3D: 80
# CCCCCCC(CCCC)O
# AutoCorr3D: 80
# CCC1=CCCC1
# AutoCorr3D: 80
# CCOc1ccc(cc1)C#N
# AutoCorr3D: 80
# Cc1c(cnn1c2ccccc2)C(=O)O
# AutoCorr3D: 80
# O=S(=O)(c1ccc(cc1)C)C[N+]#[C-]
# AutoCorr3D: 80
# COC(=O)c1cc(ccc1[N+](=O)[O-])Cl
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)C#N
# AutoCorr3D: 80
# N1=C2C=CC=CC2=C(C)C1c1ccccc1
# AutoCorr3D: 80
# CC=1CCC[C@](C)(C)C=1/C=CC(C)=CC=CC(C)=CCO
# AutoCorr3D: 80
# c1cc(c(c(c1F)C(=O)O)F)F
# AutoCorr3D: 80
# COC(=O)c1c[nH]c2c1cccc2
# AutoCorr3D: 80
# c1cc(oc1C=O)Br
# AutoCorr3D: 80
# c1cc2c(cc1/C=C/C=C/C(=O)N3CCCCC3)OCO2
# AutoCorr3D: 80
# CC=CCCCC
# AutoCorr3D: 80
# Fc1cc(C[C@H](N)C(=O)O)ccc1O
# AutoCorr3D: 80
# c1cc(c(c(c1)Cl)C(=S)N)Cl
# AutoCorr3D: 80
# O[C@@H]1CC(=O)[C@H](CCCCCCC(=O)O)[C@H]1/C=C/[C@@H](O)CCCCC
# AutoCorr3D: 80
# c1cc(cc2c1ccc(=O)o2)O
# AutoCorr3D: 80
# c1ccc(cc1)c2c(c(=O)c3c(cc(cc3o2)O)O)O
# AutoCorr3D: 80
# C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2C[C@@H]([C@H]4[C@@]3(CC[C@H](C4)O)C)O)C
# AutoCorr3D: 80
# CC=C(C)CCC
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)/C=C/c2cccc(c2)[N+](=O)[O-]
# AutoCorr3D: 80
# CCOC(=O)C=C2SC(N1CCCCC1)C(=O)N2CC
# AutoCorr3D: 80
# [O-][n+]1ccccc1S
# AutoCorr3D: 80
# C=CCCCCCCCCC(=O)O
# AutoCorr3D: 80
# O=C(C)Nc1cc(C)ccc1
# AutoCorr3D: 80
# C(C(C(CO)O)O)O
# AutoCorr3D: 80
# Cc1cc(cc(c1)O)O
# AutoCorr3D: 80
# Cc1ccnc2c1cccc2
# AutoCorr3D: 80
# Cc1ccc2ccccc2n1
# AutoCorr3D: 80
# c1cc(cc(c1)Br)Cl
# AutoCorr3D: 80
# Oc2ccc3ccccc3c2N=Nc1ccccn1
# AutoCorr3D: 80
# Cc1ccc(c(c1)OC)O
# AutoCorr3D: 80
# c1ccc(c(c1)C=O)F
# AutoCorr3D: 80
# c1ccc2c(c1)CCO2
# AutoCorr3D: 80
# Clc1ccc(Cl)c(Cl)c1Cl
# AutoCorr3D: 80
# CCc1ccncc1
# AutoCorr3D: 80
# CCc1ccc(Br)cc1
# AutoCorr3D: 80
# c1c(c(cc(c1F)F)F)F
# AutoCorr3D: 80
# COC(=O)c1cccnc1
# AutoCorr3D: 80
# c1c(cc(cc1F)F)F
# AutoCorr3D: 80
# Cc1ccc(cc1Cl)Cl
# AutoCorr3D: 80
# c1c(c(c(c(c1F)F)N)F)F
# AutoCorr3D: 80
# Cc1cc(c(cc1C)C(=O)C)C
# AutoCorr3D: 80
# c1ccc(c(c1)F)I
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)C(Cl)Cl
# AutoCorr3D: 80
# c1cc(ccc1C(=O)CCl)Cl
# AutoCorr3D: 80
# COc1cccc(c1)[N+]([O-])=O
# AutoCorr3D: 80
# CCOC(=O)c1ccc(c(c1)OC)OC
# AutoCorr3D: 80
# C(CC(=O)O)C(=O)C(=O)O
# AutoCorr3D: 80
# c1cc(c(cc1CC(=O)O)O)O
# AutoCorr3D: 80
# Cc2ccc3cc1c5ccccc5ccc1c4CCc2c34
# AutoCorr3D: 80
# CCC(C(=O)NC(=O)NC(C)=O)c1ccccc1
# AutoCorr3D: 80
# CN(C)CCC=C1c3ccccc3CCc2ccccc12
# AutoCorr3D: 80
# O=S(C)(=O)OCCCCOS(C)(=O)=O
# AutoCorr3D: 80
# NS(=O)(=O)c1ccc(cc1)n3nc(cc3c2ccc(C)cc2)C(F)(F)F
# AutoCorr3D: 80
# c1cc2c(cc1Cl)nc(o2)O
# AutoCorr3D: 80
# CCCCC2=NC1(CCCC1)C(=O)N2Cc3ccc(cc3)c4ccccc4c5nnn[nH]5
# AutoCorr3D: 80
# c1c(occ(c1=O)O)CO
# AutoCorr3D: 80
# O=Cc1ccccc1C=O
# AutoCorr3D: 80
# OC(CCN1CCCCC1)(c2ccccc2)c3ccccc3
# AutoCorr3D: 80
# CCc1nc(N)nc(N)c1c2ccc(Cl)cc2
# AutoCorr3D: 80
# CCN(Cc1ccncc1)C(=O)C(CO)c2ccccc2
# AutoCorr3D: 80
# NCCc1ccc(O)cc1
# AutoCorr3D: 80
# COc1ccc2c(c1)[nH]c3c2CCN4[C@@H]3C[C@H]5[C@@H](C4)C[C@H]([C@@H]([C@H]5C(=O)OC)OC)OC(=O)c6cc(c(c(c6)OC)OC)OC
# AutoCorr3D: 80
# CCCCCCCCCCCCCC
# AutoCorr3D: 80
# N#Cc1ccc(O)cc1
# AutoCorr3D: 80
# CCc2c(C)[nH]c3CCC(CN1CCOCC1)C(=O)c23
# AutoCorr3D: 80
# Clc1cc(ccc1OC)NC(=O)N(C)C
# AutoCorr3D: 80
# CCCN(CC1CC1)C2=C(C=C(C=C2[N+](=O)[O-])C(F)(F)F)[N+](=O)[O-]
# AutoCorr3D: 80
# CCOC(=O)Nc4ccc3Sc1ccccc1N(C(=O)CCN2CCOCC2)c3c4
# AutoCorr3D: 80
# NCCCCN
# AutoCorr3D: 80
# COC(=O)CCC(=O)OC
# AutoCorr3D: 80
# Nc1ccccc1C(=O)OC
# AutoCorr3D: 80
# Oc1ccc(cc1OC)C=O
# AutoCorr3D: 80
# Cc1cc(ccc1)[N+](=O)[O-]
# AutoCorr3D: 80
# CS(C)=O
# AutoCorr3D: 80
# NC(=O)c1cccnc1
# AutoCorr3D: 80
# O=C(O)C2=CN(CC)c1nc(C)ccc1C2=O
# AutoCorr3D: 80
# OC3N=C(c1ccccc1)c2cc(Cl)ccc2NC3=O
# AutoCorr3D: 80
# C=CCOC1=C(C=C(C=C1)CC(=O)O)Cl
# AutoCorr3D: 80
# CC[C@H](C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([C@H](C=C2)C)CC[C@@H]3C[C@H](CC(=O)O3)O)C
# AutoCorr3D: 80
# CC=CC=O
# AutoCorr3D: 80
# C1=CC=C(C=C1)C(=O)C(=O)C2=CC=CC=C2
# AutoCorr3D: 80
# C1=CC(=CC=C1[N+](=O)[O-])Cl
# AutoCorr3D: 80
# CCCCOC(=O)C1=CC=C(C=C1)N
# AutoCorr3D: 80
# O=C(OCCCC)CCC
# AutoCorr3D: 80
# C1CCCCC1
# AutoCorr3D: 80
# C
# AutoCorr3D: 80
# NC=O
# AutoCorr3D: 80
# CC
# AutoCorr3D: 80
# O=C(NNCCC(=O)NCc1ccccc1)c2ccncc2
# AutoCorr3D: 80
# ClC(Cl)(Cl)F
# AutoCorr3D: 80
# CCCCOC(=O)C=C
# AutoCorr3D: 80
# CC(=C)Cl
# AutoCorr3D: 80
# CC(=C)CCC(=C)C
# AutoCorr3D: 80
# CC(C)c1cc(c(cc1C(C)C)C(C)C)C(C)C
# AutoCorr3D: 80
# c1ccco1
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)N)[N+](=O)[O-]
# AutoCorr3D: 80
# Nc2nc(N)ncc2Cc1cc(OC)c(OC)c(OC)c1
# AutoCorr3D: 80
# CCCCCCCCCCCCCCBr
# AutoCorr3D: 80
# CC1OC(C)OC(C)O1
# AutoCorr3D: 80
# Oc1ccccc1Br
# AutoCorr3D: 80
# O=C(O)CCCCCCCC=CCCCCCC
# AutoCorr3D: 80
# C1COC1=O
# AutoCorr3D: 80
# CC(C)(OOC(C)(C)c1ccccc1)c2ccccc2
# AutoCorr3D: 80
# c1ccc(cc1)NN
# AutoCorr3D: 80
# C(CF)O
# AutoCorr3D: 80
# CC(C)(C)C
# Cc1cc(cc(C)c1CC2=NCCN2)C(C)(C)C
# AutoCorr3D: 80
# COc1cc(ccc1Cc3cn(C)c4ccc(NC(=O)OC2CCCC2)cc34)C(=O)NS(=O)(=O)c5ccccc5C
# AutoCorr3D: 80
# OCC(=O)[C@]3(O)[C@@]4(C)C[C@H](O)[C@@]2(F)[C@@H](CCC1=CC(=O)C=C[C@@]12C)[C@@H]4C[C@H]3C
# AutoCorr3D: 80
# c1c(cc(c(c1Cl)C(=O)O)Cl)Cl
# AutoCorr3D: 80
# c1cc(c(c(c1)Cl)Cl)C(=O)O
# AutoCorr3D: 80
# Cc1ccc(c(c1)O)C(=O)O
# AutoCorr3D: 80
# CC(=O)Nc1ccc2c3ccccc3Cc2c1
# AutoCorr3D: 80
# c1ccc2cc(ccc2c1)C=O
# AutoCorr3D: 80
# C[Si](C)(C)C
# AutoCorr3D: 80
# CC2(C)C1CCC2(C)C(=O)C1Br
# AutoCorr3D: 80
# CC(=O)Nc1ccc(cc1)S(=O)(=O)c2ccc(NC(C)=O)cc2
# AutoCorr3D: 80
# CCC(C)(C#CC(C)(CC)O)O
# AutoCorr3D: 80
# c1cc2cccc3c2c(c1)C(=O)OC3=O
# AutoCorr3D: 80
# c1ccc2c(c1)COC2=O
# AutoCorr3D: 80
# Cc1c(cccc1Cl)N
# AutoCorr3D: 80
# c1cscc1C(=O)O
# AutoCorr3D: 80
# c1ccc3ccccc3c1Nc2ccccc2
# AutoCorr3D: 80
# O=C1c3ccccc3Oc2ccccc12
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccccn2
# AutoCorr3D: 80
# CC(=O)OC(c1ccc(o1)[N+](=O)[O-])OC(=O)C
# AutoCorr3D: 80
# COc1cc(ccc1OC)CC(=O)O
# AutoCorr3D: 80
# CCCOC(=O)c1ccc(cc1)N
# AutoCorr3D: 80
# COc1cc(ccc1N)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cc(ccc1S(=O)(=O)Cl)Br
# AutoCorr3D: 80
# c1cc(ccc1S(=O)(=O)Cl)Cl
# AutoCorr3D: 80
# CN(C)c1ccc(cc1)[N+](=O)[O-]
# AutoCorr3D: 80
# ClC1=CC(=NCl)C=C(Cl)C1=O
# AutoCorr3D: 80
# c1ccc(cc1)NC(=N)Nc2ccccc2
# AutoCorr3D: 80
# c1cc(c(cc1N=C=O)Cl)Cl
# AutoCorr3D: 80
# CC1=NNC(=O)C1
# AutoCorr3D: 80
# Cc1cnccn1
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCC(=O)OC
# AutoCorr3D: 80
# C=CCCCCCCCCCO
# AutoCorr3D: 80
# CCCCCCCCCCCCS
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCC(=O)Cl
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCBr
# AutoCorr3D: 80
# C(C(Cl)(Cl)Cl)O
# AutoCorr3D: 80
# OC(c1ccc(Cl)cc1)(c2ccc(Cl)cc2)C(Cl)(Cl)Cl
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccccc2O
# AutoCorr3D: 80
# COc1cc(ccc1N)c2ccc(c(c2)OC)N
# AutoCorr3D: 80
# COc1cc(cc(c1O)OC)C=O
# AutoCorr3D: 80
# c1ccc(cc1)Oc2ccc(cc2)N
# AutoCorr3D: 80
# c3c5c1cccc2cccc(c12)c5cc4ccccc34
# AutoCorr3D: 80
# c1ccc2c(c1)cncn2
# AutoCorr3D: 80
# c1ccc2c(c1)cc3ccccc3n2
# AutoCorr3D: 80
# c1cc2cc[nH]c2nc1
# AutoCorr3D: 80
# c1ccc2c(c1)nco2
# AutoCorr3D: 80
# C1CN2CCN1CC2
# AutoCorr3D: 80
# COCCOc2cnc(NS(=O)(=O)c1ccccc1)nc2
# AutoCorr3D: 80
# C(C#N)C(=O)O
# AutoCorr3D: 80
# c1cc(c(c(c1)F)C(=O)O)F
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)Cl)F
# AutoCorr3D: 80
# c1cc(cc(c1)F)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)c2c(nc([nH]2)c3ccccc3)c4ccccc4
# AutoCorr3D: 80
# COc1cc(c(cc1OC)OC)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)/N=[N+](/c2ccccc2)[O-]
# AutoCorr3D: 80
# C1CC2CC1C=C2
# AutoCorr3D: 80
# c1cc(ccc1CCO)O
# AutoCorr3D: 80
# C(CCCCCCCC(=O)O)CCCCCCCO
# AutoCorr3D: 80
# OC(c1ccc(Cl)cc1)(c2ccc(Cl)cc2)C(=O)OCC
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)CCO
# AutoCorr3D: 80
# Cc1cc(c(c(c1)C)O)C
# AutoCorr3D: 80
# c1cc(c(cc1C(=O)O)[N+](=O)[O-])[N+](=O)[O-]
# AutoCorr3D: 80
# c1ccc2c(c1)CCCC2=O
# AutoCorr3D: 80
# c1ccc(cc1)CNC(=O)N
# AutoCorr3D: 80
# CCCCCCCCC(=O)CCCCCCCC
# AutoCorr3D: 80
# CC(C)CC(=O)N
# AutoCorr3D: 80
# Cc1cccc(c1N)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cnccc1CO
# AutoCorr3D: 80
# COC(=O)N
# AutoCorr3D: 80
# C=C(C(=O)O)Cl
# AutoCorr3D: 80
# CCC(C(=O)O)C(=O)O
# AutoCorr3D: 80
# c1cc(c(c(c1)O)[N+](=O)[O-])O
# AutoCorr3D: 80
# c1(c(c(c(c(c1F)F)F)F)F)C(=O)O
# AutoCorr3D: 80
# Cc1cccc(c1C)C(=O)O
# AutoCorr3D: 80
# [O-][N+](=O)c2cc(cc1ccccc12)[N+]([O-])=O
# AutoCorr3D: 80
# Cn1c2ccccc2ccc1=O
# AutoCorr3D: 80
# [O-][N+](=O)c1ccc2c3ccccc3Cc2c1
# AutoCorr3D: 80
# [O-][N+](=O)c1ccco1
# AutoCorr3D: 80
# c1cc(c(cc1[N+](=O)[O-])[N+](=O)[O-])C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)C(=O)O
# AutoCorr3D: 80
# Cc1ccc(cc1)c2ccc(cc2)C
# AutoCorr3D: 80
# c1ccc2cc(ccc2c1)C#N
# AutoCorr3D: 80
# C1CC(=O)NC1
# AutoCorr3D: 80
# Cc1ccc(cc1C)C(=O)O
# AutoCorr3D: 80
# [S+]([O-])(Cc1ccccc1)Cc1ccccc1
# AutoCorr3D: 80
# CCOc1cccc(c1)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)COC(=O)N
# AutoCorr3D: 80
# CCCOc1ccccc1
# AutoCorr3D: 80
# CC(CC(=O)O)CC(=O)O
# AutoCorr3D: 80
# CC(CCC(=O)O)CC(=O)O
# RDKit ERROR: [22:03:08]
# RDKit ERROR:
# RDKit ERROR: ****
# RDKit ERROR: Pre-condition Violation
# RDKit ERROR: molecule has no conformers
# RDKit ERROR: Violation occurred on line 238 in file /opt/conda/conda-bld/rdkit_1603173682698/work/Code/GraphMol/Descriptors/AUTOCORR3D.cpp
# RDKit ERROR: Failed Expression: mol.getNumConformers() >= 1
# RDKit ERROR: ****
# RDKit ERROR:
# RDKit ERROR: [22:05:54] UFFTYPER: Unrecognized charge state for atom: 0
# AutoCorr3D: 80
# CCCCCCC#N
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# c1ccc(cc1)C(c2ccccc2)(c3ccccc3)c4ccccc4
# AutoCorr3D: 80
# CCOC(=O)c1ccc(cc1)C(=O)OCC
# AutoCorr3D: 80
# CCC2CCC3C4CCC1CCCCC1(C)C4CCC23C
# AutoCorr3D: 80
# C(#N)C(=C(C#N)C#N)C#N
# AutoCorr3D: 80
# CP(Cl)(Cl)=O
# AutoCorr3D: 80
# Cc1[nH]ccn1
# AutoCorr3D: 80
# c1ccc2c(c1)CC(=O)OC2=O
# AutoCorr3D: 80
# CC(C)(C)C1=CC(=O)C=C(C1=O)C(C)(C)C
# AutoCorr3D: 80
# c1ccc(cc1)c2nnc(o2)c3ccccc3
# AutoCorr3D: 80
# C/C(C)=CC=C(/C)C
# AutoCorr3D: 80
# Cc1cc(nc(n1)N)C
# AutoCorr3D: 80
# Cc1cc(c(c(c1)C)S(=O)(=O)Cl)C
# AutoCorr3D: 80
# CC(Cl)C(Cl)(Cl)Cl
# AutoCorr3D: 80
# C=Cc1ccc2ccccc2c1
# AutoCorr3D: 80
# c1(c(c(c(c(c1F)F)F)F)F)NN
# AutoCorr3D: 80
# O=C1CCCCCCCCCCC1
# AutoCorr3D: 80
# Cc1ccc(cc1)C(=O)Cl
# AutoCorr3D: 80
# c1ccc(cc1)c2nc3ccccc3s2
# AutoCorr3D: 80
# Cc1cccc[n+]1[O-]
# AutoCorr3D: 80
# c1ccc2c(c1)nc(s2)O
# AutoCorr3D: 80
# c1cc(c(cc1C#N)[N+](=O)[O-])Cl
# AutoCorr3D: 80
# [O-][N+](=O)c2ccc(Nc1ccccc1)c(c2)[N+]([O-])=O
# AutoCorr3D: 80
# Cc1ccc[n+](c1)[O-]
# AutoCorr3D: 80
# COc1ccc2c(c1)CCCC2=O
# AutoCorr3D: 80
# CC(=O)c1ccncc1
# AutoCorr3D: 80
# Cc1ccnc(c1)c2cc(ccn2)C
# AutoCorr3D: 80
# c1(c(c(c(c(c1Br)Br)Br)Br)Br)Oc2c(c(c(c(c2Br)Br)Br)Br)Br
# AutoCorr3D: 80
# c1cc(c(cc1C(=O)O)S(=O)(=O)N)Cl
# AutoCorr3D: 80
# CS(=O)(=O)c1ccc(cc1)c3cn2ccccc2n3
# AutoCorr3D: 80
# c1cc(c(cc1Cl)Br)Cl
# AutoCorr3D: 80
# c1cnccc1C(=O)N
# AutoCorr3D: 80
# c1cc(ccc1N=C=S)F
# AutoCorr3D: 80
# COC(=O)c1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)P(=O)(c2ccccc2)O
# AutoCorr3D: 80
# Clc1nc(C(=O)N=C(/N)N)c(N)nc1N
# AutoCorr3D: 80
# CC(=O)c1c(cccc1OC)OC
# AutoCorr3D: 80
# C(CCBr)CC(=O)O
# AutoCorr3D: 80
# c1cc(ccc1N=C=S)Cl
# AutoCorr3D: 80
# c1cc(c(nc1)Cl)Cl
# AutoCorr3D: 80
# Clc1ccccc1CC(=O)O
# AutoCorr3D: 80
# c1c(cncc1Cl)Cl
# AutoCorr3D: 80
# CC(=O)n1ccnc1
# AutoCorr3D: 80
# c1cc(c(cc1Cl)C(=O)O)[N+](=O)[O-]
# AutoCorr3D: 80
# CCOC(=O)c1ccccn1
# AutoCorr3D: 80
# c1c(cc(c(c1Br)O)Br)C=O
# AutoCorr3D: 80
# c1cc(c(cc1C=O)[N+](=O)[O-])O
# AutoCorr3D: 80
# c1ccc(cc1)CSC#N
# AutoCorr3D: 80
# CS(=O)(=O)c1ccccc1
# AutoCorr3D: 80
# c1cc(oc1)C(=O)NN
# AutoCorr3D: 80
# C(CCCCCCBr)CCCCCBr
# AutoCorr3D: 80
# CCNc1ccc(cc1)[N+]([O-])=O
# AutoCorr3D: 80
# c1cc(ccc1N=C=S)N=C=S
# AutoCorr3D: 80
# CCc1cc(c(c(c1)C(C)(C)C)O)C(C)(C)C
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# C(CCC(=O)O)CCBr
# AutoCorr3D: 80
# c1cc(sc1C(=O)O)C(=O)O
# AutoCorr3D: 80
# C1COCCN1C=O
# AutoCorr3D: 80
# Cc1ccc(cc1)Cc2ccc(C)cc2
# AutoCorr3D: 80
# O=[N+]([O-])c1c(C)cccc1C(=O)O
# AutoCorr3D: 80
# c1ccc2c(c1)C(=O)N(C2=O)CCCBr
# AutoCorr3D: 80
# CCCCCCCC1CCCCC1
# AutoCorr3D: 80
# c1cc(sc1)C(=O)N
# AutoCorr3D: 80
# N#CSCSC#N
# AutoCorr3D: 80
# c1cc(ccc1[N+](=O)[O-])S(=O)(=O)N
# AutoCorr3D: 80
# C1CNCCC1CN
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)Cl)Br
# AutoCorr3D: 80
# BrC(Br)(C#N)C(N)=O
# AutoCorr3D: 80
# CC1(C2CCC1(C(=O)C2=O)C)C
# AutoCorr3D: 80
# CCCCCCCCCCCCC=O
# AutoCorr3D: 80
# c1ccc2c(c1)OCCOCCOc3ccccc3OCCOCCO2
# AutoCorr3D: 80
# CCCCCc1ccc(cc1)O
# AutoCorr3D: 80
# c1cc(c(c(c1)Cl)CO)Cl
# AutoCorr3D: 80
# c1cc2c(cc[nH]2)cc1C#N
# AutoCorr3D: 80
# CN1CCC(CC1)N(Cc2cccs2)c3ccccc3
# AutoCorr3D: 80
# CCCCCCCCCCCCCC(=O)OC
# AutoCorr3D: 80
# Cc1c(cc(cc1Br)Br)Br
# AutoCorr3D: 80
# Brc1cc(CC#N)ccc1
# AutoCorr3D: 80
# CC(C)NC(=O)NS(=O)(=O)c1cnccc1Nc2cccc(C)c2
# AutoCorr3D: 80
# c1ccc(c(c1)c2ccc(cc2)C(F)(F)F)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)SCC(=O)O
# AutoCorr3D: 80
# CC(C(=O)O)S
# AutoCorr3D: 80
# C1CNCCNCCCNCCNC1
# AutoCorr3D: 80
# c1ccc(cc1)c2c(c2=O)c3ccccc3
# AutoCorr3D: 80
# c1ccc(cc1)S(=O)(=O)NN
# AutoCorr3D: 80
# c1ccc(cc1)N(c2ccccc2)C(=O)Cl
# AutoCorr3D: 80
# c1cc(ccc1N=C=O)[N+](=O)[O-]
# AutoCorr3D: 80
# CN1CCC(CC1)O
# AutoCorr3D: 80
# O=C(c1cc(Cl)ccc1)c2ccccc2
# AutoCorr3D: 80
# Cc1cc(c(cc1Br)C)Br
# AutoCorr3D: 80
# c1ccc(c(c1)CBr)CBr
# AutoCorr3D: 80
# c1ccc(cc1)CN(Cc2ccccc2)c3ccccc3
# AutoCorr3D: 80
# COc1ccc(Cl)cc1N
# AutoCorr3D: 80
# O=S(N)(=O)c1ccc(Cl)cc1
# AutoCorr3D: 80
# c1ccc(cc1)CSCC(=O)O
# AutoCorr3D: 80
# CCOC=C(C#N)C#N
# AutoCorr3D: 80
# CC(=NO)C
# AutoCorr3D: 80
# c1c(c(cc(c1[N+](=O)[O-])F)F)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cc(ccc1C(=O)O)OC(F)(F)F
# AutoCorr3D: 80
# c1cc(cc(c1)C(F)(F)F)CC(=O)O
# AutoCorr3D: 80
# c1cc(ccc1C(=O)Cl)F
# AutoCorr3D: 80
# Cc1ccc(cc1[N+](=O)[O-])F
# AutoCorr3D: 80
# Cc1c(c(c(c(c1C)C)CCl)C)C
# AutoCorr3D: 80
# c1cc(sc1)c2cccs2
# AutoCorr3D: 80
# O=Cc1ccccc1N
# AutoCorr3D: 80
# c1cn(cn1)C(=O)n2ccnc2
# AutoCorr3D: 80
# c1ccc(cc1)Nc2ccc(cc2)c3ccc(cc3)Nc4ccccc4
# AutoCorr3D: 80
# c1cc2c(cc1N)scn2
# AutoCorr3D: 80
# c1cc(ccc1CBr)Br
# AutoCorr3D: 80
# CC#CC(=O)O
# AutoCorr3D: 80
# Cc1cc(ccc1O)C2(c3ccccc3C(=O)O2)c4ccc(c(c4)C)O
# AutoCorr3D: 80
# CCCCS(=O)(=O)CCCC
# AutoCorr3D: 80
# Cc1cc(c2ccccc2n1)O
# AutoCorr3D: 80
# c1cc(c(cc1[N+](=O)[O-])C(=O)O)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)Cc2ccc(cc2)c3ccccc3
# AutoCorr3D: 80
# c1cc(cc(c1)Cl)C(=O)N
# AutoCorr3D: 80
# Cc1ccc(cc1)C(=O)CBr
# AutoCorr3D: 80
# c1ccc(cc1)CS(=O)(=O)Cc2ccccc2
# AutoCorr3D: 80
# c1ccc(cc1)COc2ccc(cc2)OCc3ccccc3
# AutoCorr3D: 80
# c1ccc(cc1)OC(=O)N
# AutoCorr3D: 80
# CC(=O)OCCCCOC(=O)C
# AutoCorr3D: 80
# c1ccc(cc1)C(=C(c2ccccc2)c3ccccc3)c4ccccc4
# AutoCorr3D: 80
# O=C(C#Cc1ccccc1)O
# AutoCorr3D: 80
# c1(c(c(c(c(c1F)F)F)F)F)C(=O)N
# AutoCorr3D: 80
# c1cc(sc1)C(=O)c2cccs2
# AutoCorr3D: 80
# CC(=O)c1ccc(cc1)C(F)(F)F
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccccc2C(F)(F)F
# AutoCorr3D: 80
# COc1cc(ccc1O)O
# AutoCorr3D: 80
# COc1cc(ccc1C(C)=O)OC
# AutoCorr3D: 80
# Cn1ccc(=O)n(c1=O)C
# AutoCorr3D: 80
# COc1cccc(c1O)C(=O)O
# AutoCorr3D: 80
# Cc1cccc2c1[nH]cc2
# AutoCorr3D: 80
# Cc1ccc(cc1)OCC(=O)O
# AutoCorr3D: 80
# CCOC(=O)c1ccc(o1)[N+](=O)[O-]
# AutoCorr3D: 80
# c1ccc(cc1)COc2ccccc2
# AutoCorr3D: 80
# c1cc(ccc1)c2nnc(nc2c3ccccc3)c4ccccn4
# AutoCorr3D: 80
# c1cc2cnccc2c(c1)N
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccc(cc2)[N+](=O)[O-]
# AutoCorr3D: 80
# c1ccnc(c1)c2cccc(n2)c3ccccn3
# AutoCorr3D: 80
# O=Cc1cc(O)ccc1O
# AutoCorr3D: 80
# c1ccc(cc1)OCCCCBr
# AutoCorr3D: 80
# COc1ccc(cc1C(C)=O)OC
# AutoCorr3D: 80
# CCOc1ccc(cc1)C(C)(C)COCc3cc(Oc2ccccc2)ccc3
# AutoCorr3D: 80
# OCc1ccccc1Br
# AutoCorr3D: 80
# Clc1ccccc1OC(C)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)CCC(=O)O
# AutoCorr3D: 80
# c1ccc(c(c1)C#N)C(=O)N
# AutoCorr3D: 80
# c1ccc(cc1)CNC(=O)c2ccccc2
# AutoCorr3D: 80
# c1cc(c(cc1F)F)C(=O)O
# AutoCorr3D: 80
# c1cnc(nc1)Cl
# AutoCorr3D: 80
# c1ccc(cc1)NC2CCCCC2
# AutoCorr3D: 80
# c1cc(ccc1C(=O)N)C(F)(F)F
# AutoCorr3D: 80
# c1cc(c(c(c1)F)C#N)F
# AutoCorr3D: 80
# COc1cc(cc(c1OC)O)C(=O)O
# AutoCorr3D: 80
# CCCCCC(=O)OC(=O)CCCCC
# AutoCorr3D: 80
# c1ccc(cc1)c2ccc(cc2)C(=O)c3ccccc3
# AutoCorr3D: 80
# c1ccc2cc(ccc2c1)C(=O)Cl
# AutoCorr3D: 80
# COc1ccc(cc1)N=C=S
# AutoCorr3D: 80
# C=CCC(C(=O)O)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)c2ccccc2CO
# AutoCorr3D: 80
# c1cc(ccc1CO)C(=O)O
# AutoCorr3D: 80
# Ic1cc(Cl)cc(Cl)c1
# AutoCorr3D: 80
# c1cc(ccc1C#N)I
# AutoCorr3D: 80
# c1ccc(cc1)c2ccc(cc2)C=O
# AutoCorr3D: 80
# c1cc(cc(c1)[N+](=O)[O-])N=C=O
# AutoCorr3D: 80
# c1ccc(cc1)C(c2ccccc2)(c3ccccc3)S
# AutoCorr3D: 80
# c1cc(ncc1[N+](=O)[O-])N
# AutoCorr3D: 80
# c1ccc2c(c1)c(ccn2)C=O
# AutoCorr3D: 80
# COc1cc(ccc1O)C#N
# AutoCorr3D: 80
# c1cc2c(cc1C#N)OCO2
# AutoCorr3D: 80
# CC(CO)(CO)C(=O)O
# AutoCorr3D: 80
# O=Cc1c2c(ccc1OC)cccc2
# AutoCorr3D: 80
# O=S(=O)(C=C)c1ccccc1
# AutoCorr3D: 80
# CCC(=O)c1ccc(cc1O)O
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)NN)Cl
# AutoCorr3D: 80
# c1cc(c(cc1Cl)C#N)N
# AutoCorr3D: 80
# CCOC(=O)C(C(=O)OCC)C(=O)OCC
# AutoCorr3D: 80
# Clc1cccc(Cl)c1CC(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)P(CCCP(c2ccccc2)c3ccccc3)c4ccccc4
# AutoCorr3D: 80
# C1CN(CCN1CCCN)CCCN
# AutoCorr3D: 80
# O=C(Cl)Oc1ccc(cc1)[N+]([O-])=O
# AutoCorr3D: 80
# Cc1ccc(cc1Br)N
# AutoCorr3D: 80
# c1ccc(c(c1)c2ccccc2Br)Br
# AutoCorr3D: 80
# CC(=O)c1ccc(cc1)OC(=O)C
# AutoCorr3D: 80
# c1ccc2c(c1)OCCOCCOCCOCCO2
# AutoCorr3D: 80
# c1cc(cc2c1cc[nH]2)Cl
# AutoCorr3D: 80
# COc1cc(ccc1Br)OC
# AutoCorr3D: 80
# OC(C)(C)C1CC=C(C)C(O)C1
# AutoCorr3D: 80
# CCCCCCCCCCc1ccc(cc1)N
# AutoCorr3D: 80
# OC(=O)c1ccc(Cl)cc1OC
# AutoCorr3D: 80
# CCCCCCC(C(=O)O)O
# AutoCorr3D: 80
# c1ccc(cc1)C2CCCCC2=O
# AutoCorr3D: 80
# c1cc(ccc1C=O)I
# AutoCorr3D: 80
# CC1=C(C=C(C=C1[N+](=O)[O-])[N+](=O)[O-])C(=O)O
# AutoCorr3D: 80
# c1c(cc(cc1F)F)C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)COC(=O)N2CCC[C@H]2C(=O)O
# AutoCorr3D: 80
# [O-][N+](=O)C(COC(C)=O)C(OC(C)=O)c1ccccc1
# AutoCorr3D: 80
# C1CC(CNC1)CO
# AutoCorr3D: 80
# CC(C)CCC#C
# AutoCorr3D: 80
# CCCc1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# Cc1ccc2c(c1)no[n+]2[O-]
# AutoCorr3D: 80
# OC(C(O)C(O)C(O)C=O)C(=O)O
# AutoCorr3D: 80
# CCOc1ccc(cc1)I
# AutoCorr3D: 80
# Clc1ccc(CC#N)cc1
# AutoCorr3D: 80
# Cc1ccc(cc1)CC(=O)O
# AutoCorr3D: 80
# COc1ccc2c(c1)no[n+]2[O-]
# AutoCorr3D: 80
# CN1[C@@H]2CC[C@H]1CC(=O)C2
# AutoCorr3D: 80
# OC1CCC2(C)C3CCC4(C)C(CCC4C(C)CCCC(C)C)C3CC(O)C2(O)C1
# AutoCorr3D: 80
# Clc1ccc(/C=C/C(=O)O)cc1
# AutoCorr3D: 80
# COc1ccc(cc1)/C=C/C(=O)O
# AutoCorr3D: 80
# c1ccc(cc1)NC(=S)NN
# AutoCorr3D: 80
# Brc1ccc(/C=C/C(=O)O)cc1
# AutoCorr3D: 80
# C1C(=O)NC(=S)S1
# AutoCorr3D: 80
# Oc1ccc(cc1OC)CNC(=O)CCCC/C=C/C(C)C
# AutoCorr3D: 80
# O=C1CC(=O)NC(=S)N1
# AutoCorr3D: 80
# C1CSC(=S)N1
# AutoCorr3D: 80
# O(CCN(C)C)c1ccc(cc1)C(c1ccccc1)=C(CC)c1ccccc1
# AutoCorr3D: 80
# CCNC(=S)NCC
# AutoCorr3D: 80
# O=C1CCC2C3CCC4(C)CC5(OCCO5)CCC4(C)C3CCC12C
# AutoCorr3D: 80
# O=C1CC2CC(OC(=O)C)CCC2(C)C2CCC3(C)C(=O)CCC3C12
# AutoCorr3D: 80
# C([C@H]([C@@H]([C@@H]([C@H](C=O)O)O)O)O)O
# AutoCorr3D: 80
# c1cc(c(cc1[N+](=O)[O-])O)O
# AutoCorr3D: 80
# C=Cc1cccc(c1)C(=O)O
# AutoCorr3D: 80
# CC/C=C/CC(=O)O
# AutoCorr3D: 80
# c1ccc(c(c1)c2nc3ccccc3s2)O
# AutoCorr3D: 80
# O[C@@H](CO)[C@H](O)[C@H](O)CO
# AutoCorr3D: 80
# c1ccc(cc1)/N=N/c2ccc(cc2)O
# AutoCorr3D: 80
# Cc1ccccc1NC(=O)C
# AutoCorr3D: 80
# O=C(Nc1ccccc1)C[N+]([O-])=O
# AutoCorr3D: 80
# CCCCOC(=O)CCCCCCCCC(=O)OCCCC
# AutoCorr3D: 80
# Cc1cccc(N)c1C
# AutoCorr3D: 80
# c1ccc2c(c1)ccc(=O)o2
# AutoCorr3D: 80
# Cc1cccc(c1Cl)C
# AutoCorr3D: 80
# AutoCorr3D: 80
# [O-][N+](=O)c2cc[n+]([O-])c1ccccc12
# AutoCorr3D: 80
# O=S(=O)(OCC)OCC
# AutoCorr3D: 80
# CS(C)(=O)=O
# AutoCorr3D: 80
# Cc1ccc(cc1)S(=O)(N)=O
# AutoCorr3D: 80
# CC(C)c1cc(c(C)c(Br)c1O)C3(OS(=O)(=O)c2ccccc23)c4cc(C(C)C)c(O)c(Br)c4C
# AutoCorr3D: 80
# CC(=O)NC
# AutoCorr3D: 80
# c1ccc(cc1)c2ccccc2c3ccccc3
# AutoCorr3D: 80
# CCn3c1ccccc1c2ccccc23
# AutoCorr3D: 80
# O=C(O)c2cccc1ccccc12
# AutoCorr3D: 80
# Nc1ccc(cc1)c2ccccc2
# AutoCorr3D: 80
# c1ccc(cc1)C(CO)O
# AutoCorr3D: 80
# Clc1cc(C)c(OC(C)C(=O)O)cc1
# AutoCorr3D: 80
# O=C(Nc1ccccc1)c2ccccc2
# AutoCorr3D: 80
# Oc1ccc(O)c(C)c1
# AutoCorr3D: 80
# C(C(CBr)Br)Br
# AutoCorr3D: 80
# C(C(CCl)Cl)Cl
# AutoCorr3D: 80
# CC1CCCC1
# AutoCorr3D: 80
# CC(C)COC(=O)C(C)C
# AutoCorr3D: 80
# OC(=O)c1cc(O)ccc1
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(cc(c1)[N+]([O-])=O)C(=O)O
# AutoCorr3D: 80
# Nc1cc(ccc1OC)[N+]([O-])=O
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(C=O)ccc1
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(cc1)C(=O)OCC
# AutoCorr3D: 80
# CNc1ccc(cc1)[N+]([O-])=O
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(cc1)[N+]([O-])=O
# AutoCorr3D: 80
# CCN1CCOCC1
# AutoCorr3D: 80
# C=CCOc1nc(nc(OCC=C)n1)OCC=C
# AutoCorr3D: 80
# O=C(Nc1ccccc1)CC(C)=O
# AutoCorr3D: 80
# O=CNc1ccccc1
# AutoCorr3D: 80
# O=C(C)Nc1ccc(cc1)[N+]([O-])=O
# AutoCorr3D: 80
# O=C1CCCCCN1
# AutoCorr3D: 80
# O=C1CCC(=O)O1
# AutoCorr3D: 80
# Cc1cccc(c1)C
# AutoCorr3D: 80
# CCCCCCS
# AutoCorr3D: 80
# CCCSCCC
# AutoCorr3D: 80
# CCCCCCCCCCBr
# AutoCorr3D: 80
# CCCCCCCCCC=O
# AutoCorr3D: 80
# CCCCCCCCCCCCCCO
# AutoCorr3D: 80
# c1ccc(cc1)OC(=O)c2ccccc2O
# AutoCorr3D: 80
# c1cccc2cccc2c1
# AutoCorr3D: 80
# c1ccncn1
# AutoCorr3D: 80
# Cc2nc1ccccc1c(=O)n2c3ccccc3Cl
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(cc([N+]([O-])=O)c1Cl)C(F)(F)F
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(cc1)C(F)(F)F
# AutoCorr3D: 80
# Clc1ccc(NC(C)=O)cc1
# AutoCorr3D: 80
# CCCCl
# AutoCorr3D: 80
# ClCCC#N
# AutoCorr3D: 80
# CCC(C)(C)CC
# AutoCorr3D: 80
# CC(=C(C)C)C
# AutoCorr3D: 80
# CC(C)C(C)C(C)C
# AutoCorr3D: 80
# ...
# C1CCCCCCCOC(=O)CCCCCC1
# AutoCorr3D: 80
# Fc1cc(cc(F)c1O)C(=O)CC
# AutoCorr3D: 80
# CC(=O)Oc1ccc(cc1)c2ccc(cc2)OC(=O)C
# AutoCorr3D: 80
# c1cc(c(c(c1Cl)C(=O)O)N)Cl
# AutoCorr3D: 80
# C(/C=CCO)O
# AutoCorr3D: 80
# COC(=O)c1ccc(c(c1)[N+](=O)[O-])Cl
# AutoCorr3D: 80
# c1ccc(c(c1)/C=C/C(=O)O)[N+](=O)[O-]
# AutoCorr3D: 80
# c1cc(oc1)/C=C/C=O
# AutoCorr3D: 80
# c1ccc(cc1)/C=C/C#N
# AutoCorr3D: 80
# Cc1nnc(s1)S
# AutoCorr3D: 80
# Nc1ccc(cc1)S(=O)(=O)NC(N)=S
# AutoCorr3D: 80
# c1cc(c(cc1N)[N+](=O)[O-])O
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)NN)[N+](=O)[O-]
# AutoCorr3D: 80
# OC(C(=NO)c1ccccc1)c2ccccc2
# AutoCorr3D: 80
# c1ccc(cc1)/C=C/C(=O)c2ccc(cc2)Cl
# AutoCorr3D: 80
# c1cc(cc(c1)O)C[C@@H](C(=O)O)N
# AutoCorr3D: 80
# Cc1ccc(cc1)NC(=O)C
# AutoCorr3D: 80
# C(=C(Cl)Cl)(C(=O)O)Cl
# AutoCorr3D: 80
# C(=O)(C(F)(F)Cl)O
# AutoCorr3D: 80
# C(CC(=O)Cl)C(=O)Cl
# AutoCorr3D: 80
# O(C)c1ccc(N=Nc2ccccc2)cc1
# AutoCorr3D: 80
# c1cc(ccc1CC(=O)O)O
# AutoCorr3D: 80
# O=C(O)CO
# AutoCorr3D: 80
# O=C(O)CCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# CC(Cl)(Cl)Cl
# AutoCorr3D: 80
# IC(I)I
# AutoCorr3D: 80
# CC(C)(C)C(=O)O
# AutoCorr3D: 80
# O=C3c4ccccc4c2cccc1cccc3c12
# AutoCorr3D: 80
# Cc1ccc(Cl)cc1[N+]([O-])=O
# AutoCorr3D: 80
# Cc1cc(C)ccc1[N+](=O)[O-]
# AutoCorr3D: 80
# ClC(c1ccccc1)c2ccccc2
# AutoCorr3D: 80
# Nc1cc(Cl)c(C)cc1
# AutoCorr3D: 80
# Nc1cc(Cl)ccc1O
# AutoCorr3D: 80
# FC(F)(F)c1ccc(Cl)cc1
# AutoCorr3D: 80
# OC(=O)c1ccc(cc1Cl)[N+]([O-])=O
# AutoCorr3D: 80
# N#Cc1ccncc1
# AutoCorr3D: 80
# Brc1ccc(NC(C)=O)cc1
# AutoCorr3D: 80
# C(COc1ccccc1)Oc2ccccc2
# AutoCorr3D: 80
# ClCc1ccc(Cl)cc1
# AutoCorr3D: 80
# Clc1ccc(Br)cc1
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCO
# AutoCorr3D: 80
# O=C1N(Cl)C(=O)N(Cl)C1(C)C
# AutoCorr3D: 80
# C1CCCCCCC1
# AutoCorr3D: 80
# Oc1ccc(Cl)cc1C(=O)O
# AutoCorr3D: 80
# N=C(N)NC#N
# AutoCorr3D: 80
# CC1CCC2CC1C2(C)C
# AutoCorr3D: 80
# c1ccc2Cc3ccccc3Cc2c1
# AutoCorr3D: 80
# COc1ccc(cc1)c2ccccc2
# AutoCorr3D: 80
# c1ccc(c(c1)CC(=O)O)O
# AutoCorr3D: 80
# Ic1ccccc1N
# AutoCorr3D: 80
# Brc1cc(Br)c(O)cc1
# AutoCorr3D: 80
# OC(=O)c1ccc(I)cc1
# AutoCorr3D: 80
# N#Cc1ccc(Br)cc1
# AutoCorr3D: 80
# N#Cc1ccc(Cl)cc1
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCCCCCC
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(N)ccc1Cl
# AutoCorr3D: 80
# O=C(O)CCCCCCCCCCCC
# AutoCorr3D: 80
# c1cc(oc1C(=O)O)[N+](=O)[O-]
# AutoCorr3D: 80
# Nc2ccc(Cl)cc2C(=O)c1ccccc1
# AutoCorr3D: 80
# COc1ccc2nc(N)sc2c1
# AutoCorr3D: 80
# c1ccc(cc1)c2cccc(c2)[N+](=O)[O-]
# AutoCorr3D: 80
# O=[N+]([O-])c1cccc(C(=O)O)c1Cl
# AutoCorr3D: 80
# Nc1cc(ccc1Cl)[N+]([O-])=O
# AutoCorr3D: 80
# OCc1ccccc1Cl
# AutoCorr3D: 80
# CC(C)c1cc(c(C)cc1O)C3(OC(=O)c2ccccc23)c4cc(C(C)C)c(O)cc4C
# AutoCorr3D: 80
# c1ccc(cc1)c2ccc(cc2)C(=O)O
# AutoCorr3D: 80
# COc1ccc(cc1C=O)OC
# AutoCorr3D: 80
# COC1=CC(=O)C=C(OC)C1=O
# AutoCorr3D: 80
# COc1cc(ccc1C=O)OC
# AutoCorr3D: 80
# Ic1ccc(OC)cc1
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2ccc(cc2)C(F)(F)F
# AutoCorr3D: 80
# c1ccc(cc1)c2ccccc2C(=O)O
# AutoCorr3D: 80
# c1cc(ccc1C(=O)c2ccc(cc2)Br)Br
# AutoCorr3D: 80
# Clc1ccc(cc1Cl)C(C)=O
# AutoCorr3D: 80
# Oc1cc(ccc1)C(=O)OC
# AutoCorr3D: 80
# COc1cc2c(cc1)nccc2[C@@H](O)[C@@H]4C[C@@H]3CC[N@]4C[C@@H]3C=C
# AutoCorr3D: 80
# Brc1cc(/C=C/C(=O)O)ccc1
# AutoCorr3D: 80
# O=C(\C=C\c2ccc1c(cccc1)c2)\C=C\c2ccc1c(cccc1)c2
# AutoCorr3D: 80
# C(C(=O)O)Br
# AutoCorr3D: 80
# OCCOCCOCCO
# AutoCorr3D: 80
# CCc1ccccc1N
# AutoCorr3D: 80
# Ic1ccc(Cl)cc1
# AutoCorr3D: 80
# Oc1cc(Br)ccc1
# AutoCorr3D: 80
# Oc1cc(O)ccc1CCCCCC
# AutoCorr3D: 80
# Cc1cc(C)cc(C)n1
# AutoCorr3D: 80
# Nc1ccccc1Br
# AutoCorr3D: 80
# Cc1cc(C)c(Br)c(C)c1
# AutoCorr3D: 80
# CC(C)(C)c1ccc(Br)cc1
# AutoCorr3D: 80
# C1=CC=C(C(=C1)C(=O)O)N
# AutoCorr3D: 80
# CCCC=O
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(C=O)cc1
# AutoCorr3D: 80
# CC1=NC=C(N1C)[N+](=O)[O-]
# AutoCorr3D: 80
# OCCN4CCN(CCCN2c1ccccc1Sc3ccc(Cl)cc23)CC4
# AutoCorr3D: 80
# O=C(CO)[C@@]3(O)CC[C@H]2[C@@H]4CC\C1=C\C(=O)\C=C/[C@]1(C)[C@H]4C(=O)C[C@@]23C
# AutoCorr3D: 80
# CNC(=O)Oc2cccc1ccccc12
# AutoCorr3D: 80
# OC(=O)c1ccc(Cl)cc1
# AutoCorr3D: 80
# CI
# AutoCorr3D: 80
# O=C1NC(=O)NC(=O)C1(CCCC)CC
# AutoCorr3D: 80
# OC(c1ccccc1)c2ccccc2
# AutoCorr3D: 80
# CC(=O)c1ccc2ccccc2c1
# AutoCorr3D: 80
# COC(=O)c1ccccc1
# AutoCorr3D: 80
# Cc1ccc(cc1)S(=O)(Cl)=O
# AutoCorr3D: 80
# CCCCCCC(=O)O
# AutoCorr3D: 80
# CC(=O)CCCCCCCCC
# AutoCorr3D: 80
# CCCCOCCCC
# AutoCorr3D: 80
# Oc1ccccc1NC(C)=O
# AutoCorr3D: 80
# O=C(OC)OC
# AutoCorr3D: 80
# ICCI
# AutoCorr3D: 80
# Ic1ccc(cc1)[N+](=O)[O-]
# AutoCorr3D: 80
# CC(=O)c1ccc(cc1)I
# AutoCorr3D: 80
# OCCCCCCO
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(ccc1Cl)[N+]([O-])=O
# AutoCorr3D: 80
# Cc1cc(c(cc1Cl)C)Cl
# AutoCorr3D: 80
# Oc1ccc(Cl)cc1
# AutoCorr3D: 80
# O=C(Cc1ccccc1)Cc2ccccc2
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(Cl)ccc1
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(ccc1)C(C)=O
# AutoCorr3D: 80
# CCCC(=O)O
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(O)cc1
# AutoCorr3D: 80
# NC(=O)c1cnccn1
# AutoCorr3D: 80
# CC(=O)OCCC
# AutoCorr3D: 80
# C1=CC=C(C(=C1)C(=O)O)Cl
# AutoCorr3D: 80
# CCCCCCCCCO
# AutoCorr3D: 80
# C1=CC=C2C(=C1)C(=O)C3=CC=CC=C3S2
# AutoCorr3D: 80
# C(#Cc1ccccc1)c2ccccc2
# AutoCorr3D: 80
# C1(CC1)C(=O)O
# AutoCorr3D: 80
# Cc1ccc(cc1Cl)O
# AutoCorr3D: 80
# c1ccc(cc1)P(=O)(O)O
# AutoCorr3D: 80
# c1ccc(cc1)C2(CCCCC2)O
# AutoCorr3D: 80
# C(P(=O)(O)O)P(=O)(O)O
# AutoCorr3D: 80
# CCCCCCCCCCCCCC=O
# AutoCorr3D: 80
# O=C=Nc1ccc(cc1)N=C=O
# AutoCorr3D: 80
# CCCCCCCCOC(=O)c1cc(c(c(c1)O)O)O
# AutoCorr3D: 80
# CN(C=O)c1ccccc1
# AutoCorr3D: 80
# CCOc1ccc(cc1OC)C=O
# AutoCorr3D: 80
# c1cc2cccc(c2c(c1)N)N
# AutoCorr3D: 80
# CCc1[nH]cc(n1)C
# AutoCorr3D: 80
# c1ccc(cc1)C(c2ccccc2)C(=O)Cl
# AutoCorr3D: 80
# CC(=O)NC(=O)CN
# AutoCorr3D: 80
# CS(=O)(=O)c1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# C/C(=C/C(=O)O)/C(=O)O
# AutoCorr3D: 80
# CC=C(C)CC
# AutoCorr3D: 80
# B(c1ccccc1C)(O)O
# AutoCorr3D: 80
# CCC/C=C/C(=O)O
# AutoCorr3D: 80
# CC(=O)Nc1ccc(cc1)N
# AutoCorr3D: 80
# c1ccc(c(c1)C(=O)Cl)C(=O)Cl
# AutoCorr3D: 80
# c1cc(cnc1)N
# AutoCorr3D: 80
# c1c(cc(c(c1Cl)N)Br)Cl
# AutoCorr3D: 80
# c1cncc(c1N)N
# AutoCorr3D: 80
# CCO[Si](OCC)(OCC)OCC
# AutoCorr3D: 80
# C(c1c(c(c(c(c1F)F)F)F)F)O
# AutoCorr3D: 80
# Cc1ccc2c(c1)nc[nH]2
# AutoCorr3D: 80
# Cc1ccc(cc1)c2ccccc2
# AutoCorr3D: 80
# CP(=O)(O)O
# AutoCorr3D: 80
# Cc1ccc[nH]c1=O
# AutoCorr3D: 80
# NNC(=O)NN
# AutoCorr3D: 80
# c1cc(ccc1CC#N)C(F)(F)F
# AutoCorr3D: 80
# NCCCCCO
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(Br)ccc1Br
# AutoCorr3D: 80
# CC(N)=S
# AutoCorr3D: 80
# C[C@@H](CN)O
# AutoCorr3D: 80
# Oc1ccccc1C=Nc2ccccc2
# AutoCorr3D: 80
# c1cc(oc1)C(=O)O
# AutoCorr3D: 80
# COc1ccc(Br)cc1
# AutoCorr3D: 80
# N#Cc1ccc(cc1)C(c2ccc(C#N)cc2)n3cncn3
# AutoCorr3D: 80
# O=[N+]([O-])c1cc(ccc1N)[N+]([O-])=O
# AutoCorr3D: 80
# BrCCCCBr
# AutoCorr3D: 80
# Clc1ccc(CC(=O)O)cc1
# AutoCorr3D: 80
# OC(=O)c1cc(Cl)ccc1Cl
# AutoCorr3D: 80
# COC(=O)c1ccccc1C(=O)OC
# AutoCorr3D: 80
# Cc1cc(N)c(C)cc1
# AutoCorr3D: 80
# Cc1ccc(Br)cc1
# AutoCorr3D: 80
# Oc1c(cccc1OC)C=O
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(Cl)cc1Cl
# AutoCorr3D: 80
# Clc1cc(O)c(Cl)cc1Cl
# AutoCorr3D: 80
# Fc1ccc(O)cc1
# AutoCorr3D: 80
# CC1=C2C=CC=CC2=CC3=CC=CC=C13
# AutoCorr3D: 80
# C[C@]12CCC(=O)C=C1CC[C@@H]3[C@@H]2C(=O)C[C@]4([C@H]3CC[C@@]4(C(=O)CO)O)C
# AutoCorr3D: 80
# Cc1cccc(c1C)O
# AutoCorr3D: 80
# C1=C(C=C(C(=C1Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# NC(=O)c1ccccc1
# AutoCorr3D: 80
# OC2(CCN(CCCC(=O)c1ccc(F)cc1)CC2)c3ccc(Cl)cc3
# AutoCorr3D: 80
# CC1=C(C(=C(C(=C1C)C)C)C)C
# AutoCorr3D: 80
# COC(=O)C1=CC=C(C=C1)N
# AutoCorr3D: 80
# Clc1cccc(Cl)c1O
# AutoCorr3D: 80
# CCOC1=CC=C(C=C1)NC(=O)C
# AutoCorr3D: 80
# CCCCOC(=O)C1=CC=C(C=C1)O
# AutoCorr3D: 80
# C1COCCN1CCO
# AutoCorr3D: 80
# CC1CCC(CC1)C(C)C
# AutoCorr3D: 80
# O=C(O)CCCCCCCCC(=O)O
# AutoCorr3D: 80
# Fc1cccc(O)c1
# AutoCorr3D: 80
# CC(CC)(CO)CO
# AutoCorr3D: 80
# CC(C)CC(=O)O
# AutoCorr3D: 80
# OC1CCCC1
# AutoCorr3D: 80
# Oc3cc4CC[C@@H]1[C@H](CC[C@]2(C)C(=O)CC[C@@H]12)c4cc3
# AutoCorr3D: 80
# FC(F)(F)CC(F)(F)F
# AutoCorr3D: 80
# COC(=O)c1ccc(C)cc1
# AutoCorr3D: 80
# COc1ccccc1CC#N
# AutoCorr3D: 80
# Nc1ccc2cc3ccccc3cc2c1
# AutoCorr3D: 80
# C1(=C(C(=C(C(=C1Cl)Cl)Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# [O-][N+](=O)NC/1=N/CCN\1Cc2cnc(Cl)cc2
# AutoCorr3D: 80
# O=C(CCCCCCC)OCC
# AutoCorr3D: 80
# FC(F)(F)C(F)C(F)(F)F
# AutoCorr3D: 80
# c1cc(ccc1)c2ccc(cc2)c3ccccc3
# AutoCorr3D: 80
# Oc1ccc(Br)cc1
# AutoCorr3D: 80
# NCCC(=O)O
# AutoCorr3D: 80
# CCCC(N)C(=O)O
# AutoCorr3D: 80
# c1ccc2c(c1)c(c[nH]2)CCN
# AutoCorr3D: 80
# B(c1ccccc1)(c2ccccc2)OCCN
# AutoCorr3D: 80
# CC(=O)Nc1ccc(cc1)OC
# AutoCorr3D: 80
# CCCCC(COP(=O)(OCC(CC)CCCC)OCC(CC)CCCC)CC
# AutoCorr3D: 80
# c1ccc2c(c1)C(=O)NC2=O
# AutoCorr3D: 80
# CN(C)c1ccc(cc1)C(=O)c2ccc(cc2)N(C)C
# AutoCorr3D: 80
# CCN(CC)c1ccc2c(c1)OC(=O)C=C2C
# AutoCorr3D: 80
# c1cc2c(cc1C(=O)O)OCO2
# AutoCorr3D: 80
# Cc1cc(cc(c1)C(C)(C)C)C
# AutoCorr3D: 80
# c1ccc(cc1)CNc2ccc(cc2)O
# AutoCorr3D: 80
# C1CCNCC1
# AutoCorr3D: 80
# C12C(C(=O)OC1=O)C3(C(=C(C2(C3(Cl)Cl)Cl)Cl)Cl)Cl
# AutoCorr3D: 80
# c1ccc2c(c1)nc(s2)N
# AutoCorr3D: 80
# c1cccc5c1cc4c2c5cccc2c3ccccc34
# AutoCorr3D: 80
# c1ccc(cc1)NC(=O)NN
# AutoCorr3D: 80
# CC(C)C(C)(C)O
# AutoCorr3D: 80
# c1ccc(c(c1)CCl)Cl
# AutoCorr3D: 80
# Oc1ccc(cc1Cl)[N+]([O-])=O
# AutoCorr3D: 80
# c1ccc2c(c1)ccc(c2C=O)O
# AutoCorr3D: 80
# Cc1ccc(cc1)P(c2ccc(cc2)C)c3ccc(cc3)C
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)c2cc(ccc2N)[N+](=O)[O-]
# AutoCorr3D: 80
# OCc2cc(Oc1ccccc1)ccc2
# AutoCorr3D: 80
# C(C(CO)(CO)COCC(CO)(CO)CO)O
# AutoCorr3D: 80
# C=CCC(=O)O
# AutoCorr3D: 80
# c1cc(c(cc1[N+](=O)[O-])C=O)O
# AutoCorr3D: 80
# C(=O)(C(C(C(=O)O)(F)F)(F)F)O
# AutoCorr3D: 80
# Oc1ccc(C[C@H](NC(C)=O)C(=O)O)cc1
# AutoCorr3D: 80
# c1cc(c(cc1C(=O)O)O)[N+](=O)[O-]
# AutoCorr3D: 80
# c1ccc(cc1)C(=O)Oc2ccc(cc2)[N+](=O)[O-]
# AutoCorr3D: 80
# O=C1CCCCCCCCC1
# AutoCorr3D: 80
# Cc1cc(c(c(c1C)Br)C)C
# AutoCorr3D: 80
# c1cc(c(cc1Br)CO)O
# AutoCorr3D: 80
# COc1ccccc1C(=O)c2ccccc2
# AutoCorr3D: 80
# COC(=O)c1cc(ccc1O)Cl
# AutoCorr3D: 80
# CC(C)N(CC)C(C)C
# AutoCorr3D: 80
# C[Si](C)(C)C#C[Si](C)(C)C
# AutoCorr3D: 80
# c1cc(cc2c1cc(cc2)O)O
# AutoCorr3D: 80
# c1ccc(cc1)N/C=N/c2ccccc2
# AutoCorr3D: 80
# CCOC(=O)C(c1ccccc1)(c2ccccc2)O
# AutoCorr3D: 80
# c1ccc(c(c1)C=O)C#N
# AutoCorr3D: 80
# O[C@H](c2ccnc1ccccc12)[C@@H]4C[C@@H]3CC[N@]4C[C@@H]3C=C
# AutoCorr3D: 80
# c1cc(ccc1CC(=O)O)C(F)(F)F
# AutoCorr3D: 80
# c1ccc(c(c1)/C=C/C(=O)O)C(F)(F)F
# AutoCorr3D: 80
# O=C1CCC2C3CCC4CC(OCc5ccccc5)CCC4(C)C3CCC12C
# AutoCorr3D: 80
# c1ccc(cc1)COC(=O)/C=C/c2ccccc2
# Cc1ccc(cc1)C(=O)N
# AutoCorr3D: 80
# Cc1cc(nc2c1cccc2)Cl
# AutoCorr3D: 80
# CC(=O)Oc1ccc(cc1)OC(=O)C
# AutoCorr3D: 80
# N#Cc1ccccc1N
# AutoCorr3D: 80
# CC(=O)Nc1ccc(cc1)C=O
# AutoCorr3D: 80
# CCC(=O)CCCCCCCC
# AutoCorr3D: 80
# COc1ccc(cc1)C=Nc2ccccc2
# AutoCorr3D: 80
# N(=C/c1ccc(N(C)C)cc1)\c2ccccc2
# AutoCorr3D: 80
# C1CC=CCCCC1
# AutoCorr3D: 80
# COc1ccc(cc1)/C=C/C(=O)c2ccccc2
# AutoCorr3D: 80
# C1CNCCN1
# AutoCorr3D: 80
# OCCOCCOCC
# AutoCorr3D: 80
# COCCOCCOC
# AutoCorr3D: 80
# O=Cc1cc(O)ccc1
# AutoCorr3D: 80
# c1ccc(cc1)OCCCl
# AutoCorr3D: 80
# Oc1ccccc1OC
# AutoCorr3D: 80
# COc1ccc(cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3)Cl
# AutoCorr3D: 80
# c1ccc(cc1)CCCC(=O)O
# AutoCorr3D: 80
# O=C2c3ccccc3c1ccccc1C2=O
# AutoCorr3D: 80
# Cc1cccc(C)c1N
# AutoCorr3D: 80
# CC(C)CC(C)=O
# AutoCorr3D: 80
# CCCCCCN
# AutoCorr3D: 80
# OCC(CO)(CO)CO
# AutoCorr3D: 80
# C1C2=CC=CC=C2C3=CC4=CC=CC=C4C=C31
# AutoCorr3D: 80
# COC1=CC=CC(=C1)C(=O)O
# AutoCorr3D: 80
# Cc1c(cccc1[N+](=O)[O-])[N+]([O-])=O
# AutoCorr3D: 80
# O=[N+]([O-])c1ccccc1CCl
# AutoCorr3D: 80
# Clc1c(OC)cc(Cl)c(Cl)c1Cl
# AutoCorr3D: 80
# O=C(C)Nc1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# O=C(C)c1cccc(c1)C(C)=O
# AutoCorr3D: 80
# C1=CC(=CC=C1[N+](=O)[O-])OC2=C(C=C(C=C2)C(F)(F)F)[N+](=O)[O-]
# AutoCorr3D: 80
# CCc1ccc(O)cc1
# AutoCorr3D: 80
# Ic1ccccc1[N+](=O)[O-]
# AutoCorr3D: 80
# Oc2ccccc2c1ccccc1
# AutoCorr3D: 80
# ClC(Cl)(Cl)c1ccccc1
# AutoCorr3D: 80
# OCC=Cc1ccccc1
# AutoCorr3D: 80
# COc1ccc(OC)cc1
# AutoCorr3D: 80
# CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(C)=O
# AutoCorr3D: 80
# C1=CC=C2C(=C1)C3=CC=CC=C3N2
# AutoCorr3D: 80
# O=C(Oc1ccccc1)c2ccccc2
# AutoCorr3D: 80
# CN(C)C(=O)NC1=CC=C(C=C1)Cl
# AutoCorr3D: 80
# C1=C(C(=CC(=C1Br)Br)Br)Br
# AutoCorr3D: 80
# O=[N+]([O-])c1ccc(N)cc1
# AutoCorr3D: 80
# O=S(=O)(N(CCC)CCC)c1ccc(cc1)C(=O)O
# AutoCorr3D: 80
# C1=CC=C2C(=C1)C=CC3=CC4=C(C=CC5=CC=CC=C54)C=C32
# AutoCorr3D: 80
# C1=CC=C(C(=C1)C(=O)O)Br
# AutoCorr3D: 80
# O=[N+]([O-])c1cccc(O)c1
# AutoCorr3D: 80
# C1=CC(=CC=C1C(=O)O)Br
# AutoCorr3D: 80
# C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl
# AutoCorr3D: 80
# C1=CC(=C(C=C1[N+](=O)[O-])Cl)Cl
# AutoCorr3D: 80
# C1=CC=C(C=C1)CCC2=CC=CC=C2
# AutoCorr3D: 80
# C1=CC=C2C(=C1)NC3=CC=CC=C3S2
# AutoCorr3D: 80
# COC(=O)C1=CC=C(C=C1)O
# AutoCorr3D: 80
# CCOC(=O)C1=CC=C(C=C1)N
# AutoCorr3D: 80
# C1=CC=C(C(=C1)C(=O)O)O
# AutoCorr3D: 80
# C=CC=C
# AutoCorr3D: 80
# CC#N
# AutoCorr3D: 80
# CCCCOCCO
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCCCO
# AutoCorr3D: 80
# Cc1cccc(c1)C=C
# AutoCorr3D: 80
# CC(O)(C#C)c1ccccc1
# AutoCorr3D: 80
# CC1=CC=CC=C1C(=O)O
# AutoCorr3D: 80
# BrCCCCCCBr
# AutoCorr3D: 80
# c1cc(cc(c1)I)I
# AutoCorr3D: 80
# OCCCCO
# AutoCorr3D: 80
# CC1CCC(C)C1C
# AutoCorr3D: 80
# C(C(CO)([N+](=O)[O-])Br)O
# AutoCorr3D: 80
# c1ccc(cc1)COC(=O)CCC(=O)OCc2ccccc2
# AutoCorr3D: 80
# COc1ccc(c(c1)O)C(=O)c2ccc(cc2O)OC
# AutoCorr3D: 80
# c1c(cc(c(c1C(=O)O)O)I)I
# AutoCorr3D: 80
# c1cc(ccc1C(=O)c2ccc(cc2)F)F
# AutoCorr3D: 80
# c1ccc(c(c1)c2ccccc2C(=O)O)C(=O)O
# AutoCorr3D: 80
# O=C(O)c4ccccc4C=2c3cc(Br)c(O)c(Br)c3OC=1C=2C=C(Br)C(=O)C=1Br
# AutoCorr3D: 80
# CCCCCCCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-20305d2f1c5e> in <module>
#      10     #AllChem.EmbedMolecule(tmol,ps)
#      11     AllChem.EmbedMolecule(tmol)
# ---> 12     print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(tmol)))
#
# RuntimeError: Pre-condition Violation
# 	molecule has no conformers
# 	Violation occurred on line 238 in file Code/GraphMol/Descriptors/AUTOCORR3D.cpp
# 	Failed Expression: mol.getNumConformers() >= 1
# 	RDKIT: 2020.09.1
# 	BOOST: 1_73

# %%
tsmile = "CCCCCCCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC"

#params = Chem.SmilesParserParams()
#params.removeHs = False

#tmol = Chem.MolFromSmiles(tsmiles, params)
#tmol
tmol = Chem.MolFromSmiles(tsmiles)
AllChem.EmbedMolecule(tmol)
#tmol.UpdatePropertyCache(strict=False)
print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(tmol)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-6fbee2d555de> in <module>
#       9 AllChem.EmbedMolecule(tmol)
#      10 #tmol.UpdatePropertyCache(strict=False)
# ---> 11 print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(tmol)))
#
# RuntimeError: Pre-condition Violation
# 	molecule has no conformers
# 	Violation occurred on line 238 in file Code/GraphMol/Descriptors/AUTOCORR3D.cpp
# 	Failed Expression: mol.getNumConformers() >= 1
# 	RDKIT: 2020.09.1
# 	BOOST: 1_73

# %%
tmol

# %%
tmol = Chem.AddHs(tmol)
#tmol
AllChem.EmbedMolecule(tmol)
AllChem.EmbedMolecule(tmol, useRandomCoords=True)
#AllChem.UFFOptimizeMolecule(tmol)
#tmol.UpdatePropertyCache(strict=False)
print("AutoCorr3D:",len(rdMolDescriptors.CalcAUTOCORR3D(tmol)))
# Out:
# AutoCorr3D: 80

# %%
tmol

# %%
AllChem.EmbedMolecule(tmol, useRandomCoords=True)
# Out:
# 0

# %%
print ("The shape of the fingerprint is", X.shape)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor

# %%
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import rbf_kernel

from sklearn.model_selection import cross_val_score

import pickle


def make_scatter_plot(y_pred_train, y_pred_test, y_train, y_test, title, figsize, fontsize, fname):    
    plt.clf()
    f = plt.figure(figsize=figsize)
    plt.scatter(y_train,y_pred_train, label = 'Train', c='blue')
    plt.title(title,fontsize=fontsize+5)
    plt.xlabel('Experimental Melting Temperature (C)', fontsize=fontsize)
    plt.ylabel('Predicted Melting Temperature (C)', fontsize=fontsize)
    plt.scatter(y_test,y_pred_test,c='lightgreen', label='Test', alpha = 0.8)
    plt.legend(loc=4)
    #plt.xlim(-200,500)
    #plt.ylim(-200,500)
    plt.show()
    f.savefig(fname+".pdf")

from sklearn.model_selection import train_test_split

def test_models_and_plot(x, y, model_dict, plots, fp_case, fp_len):
    ''' test a bunch of models and print out a sorted list of CV accuracies
        inputs: 
            x: training data features, numpy array or Pandas dataframe
            y: training data labels, numpy array or Pandas dataframe
            model_dict: a dictionary of the form {name : model()}, where 'name' is a string
                        and 'model()' is a scikit-learn model object. 
    '''

    mean_scores = {}
    percent_errors = {}
    
    for (name, model) in model_dict.items():
        #print("running %s" % name)
        scores = cross_val_score(model, x, y, cv=20, n_jobs=-1, scoring='neg_mean_absolute_error')
        scores = -1*scores
        mean_score = scores.mean()
        mean_scores[name] = mean_score

        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
        model.fit(X_train, y_train)
        # save the model to disk
        filename = name + "_" + str(fp_case) + "_" + str(fp_len) + ".sav"
        pickle.dump(model, open(filename, 'wb'))
        
        y_pred_train = model.predict(X_train)
        mae_train = np.mean(np.abs(y_train-y_pred_train))
        max_train = np.max(np.abs(y_train-y_pred_train))
        y_pred_test  = model.predict(X_test)
        mae_test = np.mean( np.abs(y_test -y_pred_test))
        max_test = np.max( np.abs(y_test -y_pred_test) )
        
        percent_errors[name] = mae_test

        #fulltitle = name+'\n MAE error: '+str(percent_error)
        fulltitle = name + \
            "\n MAE train: " +  str("{:.2f}".format(mae_train)) + "; max diff train: " +  str("{:.2f}".format(max_train)) + \
            "\n MAE test: " +  str("{:.2f}".format(mae_test)) + "; max diff test: " +  str("{:.2f}".format(max_test))
        

        if plots:
            fname = name + "_" + str(fp_case) + "_" + str(fp_len)
            make_scatter_plot(y_pred_train, y_pred_test, y_train, y_test, fulltitle, (8,8), 16, fname)

    sorted_names = sorted(percent_errors, key=mean_scores.__getitem__, reverse=False)

    print("\\begin{tabular}{c c c}")
    print("           name     &     test MAE err   & .    abs error in CV \\\\ ")
    print("\\hline")
    for i in range(len(sorted_names)):
        name = sorted_names[i]
        print("%30s & %5.3f & %5.3f \\\\" % (name, percent_errors[name], mean_scores[name]))
    print("\\end{tabular}")


alpha_grid = {'alpha': np.logspace(1e-11,1e-1,8)}

model_dict = {
            #'Linear_Regression': LinearRegression(),
            #'Kernel Ridge Regression': KernelRidge(),
            #'Ridge Regression':Ridge(),
            #'Gaussian Process Regressor': GaussianProcessRegressor(normalize_y=True),
            #'Support Vector Regression': SVR(),
            #'KNeighborsRegressor': KNeighborsRegressor(),
            'Gradient_Boosted_Trees': GradientBoostingRegressor(n_estimators=100),
            'Random_forest': RandomForestRegressor(n_estimators=100),
            'Neural_Network': MLPRegressor(alpha=0.01,max_iter=8000, hidden_layer_sizes=[80,60], early_stopping=False)
            }

test_models_and_plot(X, y, model_dict, plots=True, fp_case=fp_case, fp_len=fp_len)

# %%
import glob

filename = "A.txt"
print("read SMILES from file:", filename)
smiles = np.loadtxt(filename, dtype=str)

for tsmiles in smiles:
    print ("**********************************")
    print (tsmiles)
    tmol = Chem.MolFromSmiles(tsmiles)
    fp = generate_fingerprint(tmol, fp_case, fp_len)
    X = np.array(list(fp))
    
    X1 = []
    if fp_element_count:
        Zelement = 6
        X1.append(element_count(tmol, Zelement))
        Zelement = 7
        X1.append(element_count(tmol, Zelement))
        Zelement = 8
        X1.append(element_count(tmol, Zelement))
        X1 = np.array(X1)
        X = np.concatenate((X,X1), axis=0)
    if fp_add_fp2:
        fp_2 = generate_fingerprint(tmol, fp_case+1, fp_len)
        X2 = np.array(list(fp_2))
        X = np.concatenate((X,X2), axis=0)
    if fp_add_fp3:
        fp_3 = generate_fingerprint(tmol, fp_case+2, fp_len)
        X3 = np.array(list(fp_3))
        X = np.concatenate((X,X3), axis=0)

        
    nlen = X.shape[0]
    X = np.reshape(X, (1, nlen)) 
    print ("The shape of the fingerprint is", X.shape)
    X = st.transform(X)
    
    postname = "_" + str(fp_case) + "_" + str(fp_len) + ".sav"
    files_model = glob.glob('*'+postname)
    for f in files_model:
        model = pickle.load(open(f, 'rb'))
        y_pred = model.predict(X)
        print (f, y_pred)
